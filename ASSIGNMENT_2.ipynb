# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'is-the-traffic-collision-fatal:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-competitions-data%2Fkaggle-v2%2F70315%2F7736702%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240314%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240314T202233Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading is-the-traffic-collision-fatal, 814014 bytes compressed
# [==================================================] 814014 bytes downloaded
# Downloaded and uncompressed: is-the-traffic-collision-fatal
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/is-the-traffic-collision-fatal/Test.csv
# /kaggle/input/is-the-traffic-collision-fatal/Train.csv

# %% [markdown]
# # Minimum Requirements Met
# (5 marks)
# -------------------------------------------------------------------------------------------------
# ## All requirements met.
# ### Applied multiple (>=4) Machine learning Techniques.
# (1 mark)
#
# ### Data preprocessing using Sklearn pipeline present in the solution.
# (1 mark)
#
# ### Presented all the metrics (MSE, RMSE, MAE, R-Square, Adjusted R-Square (for Regression) Precision, Recall, Accuracy, AUC, F1 Score (For Classification). Include Test Set Results from Kaggle.
# (1 mark)
#
# ### Grid Search / Randomized Search / Bayesian Optimization
# (1 mark)
#
# ### Feature Importance shown for all algorithms.
# (1 mark)

# %% [markdown]
# ## Coding practices
# (5 Marks)
# ### The code is well-commented, and well explained for all the steps throughout the notebook especially in areas that you found difficult to program.(1 Marks)
#
# ### Proper use of Variable names, following the best practices.
# (1 Mark)
#
# ### Use of Python Methods (definitions and classes) to avoid repetition of code.
# (3 Marks)

# %% [markdown]
# ## Presentation skills and Time taken (5 marks)
#
# ### The Group showed great presentation skills and story telling skills.
# (3 Marks)
#
# ### The Group finished their presentation within the 10 minutes deadline.
# (1 Mark)
#
# ### The Group answered all the questions correctly, asked by the instructor.
# (1 Marks)

# %%
df = pd.read_csv("/kaggle/input/is-the-traffic-collision-fatal/Train.csv")
dfts = pd.read_csv("/kaggle/input/is-the-traffic-collision-fatal/Test.csv")

# %%
df
# Out:
#          INDEX_    ACCNUM  YEAR                    DATE  TIME  \
# 0       3387730  892658.0  2006  2006/03/11 05:00:00+00   852
# 1       3387731  892658.0  2006  2006/03/11 05:00:00+00   852
# 2       3388101  892810.0  2006  2006/03/11 05:00:00+00   915
# 3       3389067  893184.0  2006  2006/01/01 05:00:00+00   236
# 4       3388102  892810.0  2006  2006/03/11 05:00:00+00   915
# ...         ...       ...   ...                     ...   ...
# 14995  81474608       NaN  2018  2018/04/26 04:00:00+00  1942
# 14996  81474609       NaN  2018  2018/04/26 04:00:00+00  1942
# 14997  81474610       NaN  2018  2018/04/26 04:00:00+00  1942
# 14998  81474611       NaN  2018  2018/04/26 04:00:00+00  1942
# 14999  81474612       NaN  2018  2018/04/26 04:00:00+00  1942
#
#                STREET1         STREET2 OFFSET      ROAD_CLASS  \
# 0           BLOOR ST W     DUNDAS ST W    NaN  Major Arterial
# 1           BLOOR ST W     DUNDAS ST W    NaN  Major Arterial
# 2      MORNINGSIDE AVE  SHEPPARD AVE E    NaN  Major Arterial
# 3         WOODBINE AVE     O CONNOR DR    NaN  Major Arterial
# 4      MORNINGSIDE AVE  SHEPPARD AVE E    NaN  Major Arterial
# ...                ...             ...    ...             ...
# 14995    ISLINGTON AVE       ALBION RD    NaN  Major Arterial
# 14996    ISLINGTON AVE       ALBION RD    NaN  Major Arterial
# 14997    ISLINGTON AVE       ALBION RD    NaN  Major Arterial
# 14998    ISLINGTON AVE       ALBION RD    NaN  Major Arterial
# 14999    ISLINGTON AVE       ALBION RD    NaN  Major Arterial
#
#                     DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 0      Toronto and East York        4  43.656345 -79.452490  Intersection
# 1      Toronto and East York        4  43.656345 -79.452490  Intersection
# 2                Scarborough       25  43.801943 -79.199786  Intersection
# 3      Toronto and East York       19  43.699595 -79.318797  Intersection
# 4                Scarborough       25  43.801943 -79.199786  Intersection
# ...                      ...      ...        ...        ...           ...
# 14995         Etobicoke York        1  43.737166 -79.565257  Intersection
# 14996         Etobicoke York        1  43.737166 -79.565257  Intersection
# 14997         Etobicoke York        1  43.737166 -79.565257  Intersection
# 14998         Etobicoke York        1  43.737166 -79.565257  Intersection
# 14999         Etobicoke York        1  43.737166 -79.565257  Intersection
#
#                      ACCLOC        TRAFFCTL VISIBILITY             LIGHT  \
# 0           At Intersection  Traffic Signal      Clear          Daylight
# 1           At Intersection  Traffic Signal      Clear          Daylight
# 2           At Intersection  Traffic Signal      Clear          Daylight
# 3      Intersection Related      No Control      Clear              Dark
# 4           At Intersection  Traffic Signal      Clear          Daylight
# ...                     ...             ...        ...               ...
# 14995       At Intersection  Traffic Signal      Clear  Dusk, artificial
# 14996       At Intersection  Traffic Signal      Clear  Dusk, artificial
# 14997       At Intersection  Traffic Signal      Clear  Dusk, artificial
# 14998       At Intersection  Traffic Signal      Clear  Dusk, artificial
# 14999       At Intersection  Traffic Signal      Clear  Dusk, artificial
#
#       RDSFCOND           ACCLASS              IMPACTYPE            INVTYPE  \
# 0          Dry             Fatal  Pedestrian Collisions             Driver
# 1          Dry             Fatal  Pedestrian Collisions         Pedestrian
# 2          Dry             Fatal       Turning Movement  Motorcycle Driver
# 3          Wet  Non-Fatal Injury            Approaching          Passenger
# 4          Dry             Fatal       Turning Movement             Driver
# ...        ...               ...                    ...                ...
# 14995      Dry  Non-Fatal Injury       Turning Movement          Passenger
# 14996      Dry  Non-Fatal Injury       Turning Movement          Passenger
# 14997      Dry  Non-Fatal Injury       Turning Movement          Passenger
# 14998      Dry  Non-Fatal Injury       Turning Movement          Passenger
# 14999      Dry  Non-Fatal Injury       Turning Movement          Passenger
#
#          INVAGE INJURY  FATAL_NO INITDIR                    VEHTYPE  \
# 0       unknown   None       NaN   South  Automobile, Station Wagon
# 1      65 to 69  Fatal       NaN   North                      Other
# 2      45 to 49  Fatal       NaN    East                 Motorcycle
# 3      50 to 54  Major       NaN     NaN                        NaN
# 4       unknown   None       NaN   South  Automobile, Station Wagon
# ...         ...    ...       ...     ...                        ...
# 14995  25 to 29   None       NaN     NaN                        NaN
# 14996    0 to 4  Minor       NaN     NaN                        NaN
# 14997    5 to 9   None       NaN     NaN                        NaN
# 14998    5 to 9   None       NaN     NaN                        NaN
# 14999  20 to 24   None       NaN     NaN                        NaN
#
#            MANOEUVER                       DRIVACT DRIVCOND  \
# 0       Turning Left  Failed to Yield Right of Way  Unknown
# 1                NaN                           NaN      NaN
# 2      Turning Right     Disobeyed Traffic Control  Unknown
# 3                NaN                           NaN      NaN
# 4        Going Ahead              Driving Properly  Unknown
# ...              ...                           ...      ...
# 14995            NaN                           NaN      NaN
# 14996            NaN                           NaN      NaN
# 14997            NaN                           NaN      NaN
# 14998            NaN                           NaN      NaN
# 14999            NaN                           NaN      NaN
#
#                                                  PEDTYPE  \
# 0                                                    NaN
# 1      Vehicle turns left while ped crosses with ROW ...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14995                                                NaN
# 14996                                                NaN
# 14997                                                NaN
# 14998                                                NaN
# 14999                                                NaN
#
#                            PEDACT  PEDCOND CYCLISTYPE CYCACT CYCCOND  \
# 0                             NaN      NaN        NaN    NaN     NaN
# 1      Crossing with right of way  Unknown        NaN    NaN     NaN
# 2                             NaN      NaN        NaN    NaN     NaN
# 3                             NaN      NaN        NaN    NaN     NaN
# 4                             NaN      NaN        NaN    NaN     NaN
# ...                           ...      ...        ...    ...     ...
# 14995                         NaN      NaN        NaN    NaN     NaN
# 14996                         NaN      NaN        NaN    NaN     NaN
# 14997                         NaN      NaN        NaN    NaN     NaN
# 14998                         NaN      NaN        NaN    NaN     NaN
# 14999                         NaN      NaN        NaN    NaN     NaN
#
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 0            Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 1            Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 2            NaN     NaN        Yes        Yes   NaN           NaN       NaN
# 3            NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 4            NaN     NaN        Yes        Yes   NaN           NaN       NaN
# ...          ...     ...        ...        ...   ...           ...       ...
# 14995        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14996        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14997        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14998        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14999        NaN     NaN        Yes        NaN   NaN           NaN       NaN
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 0           NaN      NaN     Yes      NaN     NaN        NaN       88
# 1           NaN      NaN     Yes      NaN     NaN        NaN       88
# 2           NaN      NaN     Yes      Yes     NaN        NaN      146
# 3           Yes      Yes     Yes      NaN     Yes        NaN       60
# 4           NaN      NaN     Yes      Yes     NaN        NaN      146
# ...         ...      ...     ...      ...     ...        ...      ...
# 14995       Yes      NaN     Yes      NaN     NaN        NaN        3
# 14996       Yes      NaN     Yes      NaN     NaN        NaN        3
# 14997       Yes      NaN     Yes      NaN     NaN        NaN        3
# 14998       Yes      NaN     Yes      NaN     NaN        NaN        3
# 14999       Yes      NaN     Yes      NaN     NaN        NaN        3
#
#                   NEIGHBOURHOOD_158 HOOD_140  \
# 0                   High Park North       88
# 1                   High Park North       88
# 2                      Malvern East      132
# 3                  Woodbine-Lumsden       60
# 4                      Malvern East      132
# ...                             ...      ...
# 14995  Thistletown-Beaumond Heights        3
# 14996  Thistletown-Beaumond Heights        3
# 14997  Thistletown-Beaumond Heights        3
# 14998  Thistletown-Beaumond Heights        3
# 14999  Thistletown-Beaumond Heights        3
#
#                       NEIGHBOURHOOD_140 DIVISION  ObjectId
# 0                  High Park North (88)      D11         1
# 1                  High Park North (88)      D11         2
# 2                         Malvern (132)      D42         3
# 3                 Woodbine-Lumsden (60)      D55         4
# 4                         Malvern (132)      D42         5
# ...                                 ...      ...       ...
# 14995  Thistletown-Beaumond Heights (3)      D23     14996
# 14996  Thistletown-Beaumond Heights (3)      D23     14997
# 14997  Thistletown-Beaumond Heights (3)      D23     14998
# 14998  Thistletown-Beaumond Heights (3)      D23     14999
# 14999  Thistletown-Beaumond Heights (3)      D23     15000
#
# [15000 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 55 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   INDEX_             15000 non-null  int64
#  1   ACCNUM             11302 non-null  float64
#  2   YEAR               15000 non-null  int64
#  3   DATE               15000 non-null  object
#  4   TIME               15000 non-null  int64
#  5   STREET1            15000 non-null  object
#  6   STREET2            13657 non-null  object
#  7   OFFSET             1928 non-null   object
#  8   ROAD_CLASS         14643 non-null  object
#  9   DISTRICT           14986 non-null  object
#  10  WARDNUM            15000 non-null  int64
#  11  LATITUDE           15000 non-null  float64
#  12  LONGITUDE          15000 non-null  float64
#  13  LOCCOORD           14910 non-null  object
#  14  ACCLOC             9550 non-null   object
#  15  TRAFFCTL           14971 non-null  object
#  16  VISIBILITY         14986 non-null  object
#  17  LIGHT              15000 non-null  object
#  18  RDSFCOND           14981 non-null  object
#  19  ACCLASS            15000 non-null  object
#  20  IMPACTYPE          15000 non-null  object
#  21  INVTYPE            14990 non-null  object
#  22  INVAGE             15000 non-null  object
#  23  INJURY             13394 non-null  object
#  24  FATAL_NO           593 non-null    float64
#  25  INITDIR            10502 non-null  object
#  26  VEHTYPE            12945 non-null  object
#  27  MANOEUVER          8486 non-null   object
#  28  DRIVACT            7425 non-null   object
#  29  DRIVCOND           7421 non-null   object
#  30  PEDTYPE            2460 non-null   object
#  31  PEDACT             2450 non-null   object
#  32  PEDCOND            2445 non-null   object
#  33  CYCLISTYPE         635 non-null    object
#  34  CYCACT             621 non-null    object
#  35  CYCCOND            620 non-null    object
#  36  PEDESTRIAN         5966 non-null   object
#  37  CYCLIST            1578 non-null   object
#  38  AUTOMOBILE         13672 non-null  object
#  39  MOTORCYCLE         1162 non-null   object
#  40  TRUCK              933 non-null    object
#  41  TRSN_CITY_VEH      923 non-null    object
#  42  EMERG_VEH          19 non-null     object
#  43  PASSENGER          5633 non-null   object
#  44  SPEEDING           1998 non-null   object
#  45  AG_DRIV            7696 non-null   object
#  46  REDLIGHT           1275 non-null   object
#  47  ALCOHOL            672 non-null    object
#  48  DISABILITY         420 non-null    object
#  49  HOOD_158           15000 non-null  object
#  50  NEIGHBOURHOOD_158  15000 non-null  object
#  51  HOOD_140           15000 non-null  object
#  52  NEIGHBOURHOOD_140  15000 non-null  object
#  53  DIVISION           15000 non-null  object
#  54  ObjectId           15000 non-null  int64
# dtypes: float64(4), int64(5), object(46)
# memory usage: 6.3+ MB

# %%
import plotly.express as px
# Assuming 'df' is your DataFrame containing the data
# Replace 'RDSFCOND' with the actual column name containing road conditions data

# Group by road conditions and count the frequency of each
road_condition_counts = df['RDSFCOND'].value_counts().reset_index()
road_condition_counts.columns = ['Road Condition', 'Frequency']

# Create a bar plot using Plotly
fig = px.bar(road_condition_counts, x='Road Condition', y='Frequency',
             title='Frequency of Road Conditions in Traffic Collisions',
             labels={'Frequency': 'Collision Count', 'Road Condition': 'Road Condition'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f9ece29a-2525-43c7-8b25-21542cbd3a14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9ece29a-2525-43c7-8b25-21542cbd3a14")) {                    Plotly.newPlot(                        "f9ece29a-2525-43c7-8b25-21542cbd3a14",                        [{"alignmentgroup":"True","hovertemplate":"Road Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Dry","Wet","Loose Snow","Other","Slush","Ice","Packed Snow","Loose Sand or Gravel","Spilled liquid"],"xaxis":"x","y":[11950,2549,144,135,94,63,40,5,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0. ...

# %%
# Group by state and road conditions, and count the frequency of each
state_road_condition_counts = df.groupby(['DISTRICT', 'RDSFCOND']).size().reset_index(name='Frequency')

# Create a bar plot using Plotly
fig = px.bar(state_road_condition_counts, x='DISTRICT', y='Frequency', color='RDSFCOND',
             title='Frequency of Road Conditions by State',
             labels={'Frequency': 'Collision Count', 'DISTRICT': 'State', 'RDSFCOND': 'Road Condition'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="94ab0194-065f-4701-b598-f229e6fc6839" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94ab0194-065f-4701-b598-f229e6fc6839")) {                    Plotly.newPlot(                        "94ab0194-065f-4701-b598-f229e6fc6839",                        [{"alignmentgroup":"True","hovertemplate":"Road Condition=Dry\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Dry","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Dry","offsetgroup":"Dry","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[2813,2379,2575,4175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Ice\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ice","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Ice","offsetgroup":"Ice","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[14,11,16,22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Loose Sand or Gravel\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loose Sand or Gravel","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Loose Sand or Gravel","offsetgroup":"Loose Sand or Gravel","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","Scarborough"],"xaxis":"x","y":[3,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Loose Snow\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Loose Snow","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Loose Snow","offsetgroup":"Loose Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[34,25,21,64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Other\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[42,19,24,50],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Packed Snow\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Packed Snow","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Packed Snow","offsetgroup":"Packed Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[10,8,7,15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Slush\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Slush","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Slush","offsetgroup":"Slush","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[22,23,17,32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Road Condition=Wet\u003cbr\u003eState=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e", ...

# %%
# Group by road conditions and visibility, and count the frequency of each
condition_counts = df.groupby(['RDSFCOND', 'VISIBILITY']).size().reset_index(name='Frequency')

# Create a bar plot using Plotly
fig = px.bar(condition_counts, x='RDSFCOND', y='Frequency', color='VISIBILITY',
             title='Frequency of Collisions by Road Conditions and Visibility',
             labels={'Frequency': 'Collision Count', 'RDSFCOND': 'Road Condition', 'VISIBILITY': 'Visibility'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="93885035-51ca-4d4a-b83e-f101399e13e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93885035-51ca-4d4a-b83e-f101399e13e6")) {                    Plotly.newPlot(                        "93885035-51ca-4d4a-b83e-f101399e13e6",                        [{"alignmentgroup":"True","hovertemplate":"Visibility=Clear\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Ice","Loose Sand or Gravel","Loose Snow","Other","Packed Snow","Slush","Spilled liquid","Wet"],"xaxis":"x","y":[11915,16,5,31,58,3,33,1,802],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Drifting Snow\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drifting Snow","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Drifting Snow","offsetgroup":"Drifting Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Ice","Wet"],"xaxis":"x","y":[2,5,10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Fog, Mist, Smoke, Dust\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fog, Mist, Smoke, Dust","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fog, Mist, Smoke, Dust","offsetgroup":"Fog, Mist, Smoke, Dust","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Wet"],"xaxis":"x","y":[17,27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Other\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Other","Wet"],"xaxis":"x","y":[12,73,6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Rain\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rain","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Rain","offsetgroup":"Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Packed Snow","Slush","Wet"],"xaxis":"x","y":[2,3,8,1600],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Snow\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Snow","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Snow","offsetgroup":"Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dry","Ice","Loose Snow","Other","Packed Snow","Slush","Wet"],"xaxis":"x","y":[2,24,113,4,34,37,89],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Freezing Rain\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freezing Rain","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Freezing Rain","offsetgroup":"Freezing Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Ice","Slush","Wet"],"xaxis":"x","y":[15,14,12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility=Strong wind\u003cbr\u003eRoad Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Strong wind","marker":{"color":"#B6E880","pattern":{"shape":""}},"n ...

# %%
# Group by year and count the occurrences of collisions
yearly_collision_counts = df['YEAR'].value_counts().reset_index()
yearly_collision_counts.columns = ['Year', 'Collision Count']

# Sort the DataFrame by year
yearly_collision_counts = yearly_collision_counts.sort_values(by='Year')

# Create a line plot using Plotly
fig = px.bar(yearly_collision_counts, x='Year', y='Collision Count',
              title='Year-wise Occurrence of Collisions',
              labels={'Collision Count': 'Collision Count', 'Year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cb68c58f-f343-4a36-8b43-fff55cb7a228" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb68c58f-f343-4a36-8b43-fff55cb7a228")) {                    Plotly.newPlot(                        "cb68c58f-f343-4a36-8b43-fff55cb7a228",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[1483,1474,1239,1242,1190,1179,1348,1232,916,929,1006,980,782],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"} ...

# %%
# Group by year and state and count the occurrences of collisions
state_yearly_collision_counts = df.groupby(['DISTRICT', 'YEAR']).size().reset_index(name='Collision Count')

# Sort the DataFrame by year
state_yearly_collision_counts = state_yearly_collision_counts.sort_values(by=['DISTRICT', 'YEAR'])

# Create a grouped bar plot using Plotly
fig = px.bar(state_yearly_collision_counts, x='YEAR', y='Collision Count', color='DISTRICT',
             title='Year-wise Occurrence of Collisions by State',
             labels={'Collision Count': 'Collision Count', 'YEAR': 'Year', 'DISTRICT': 'State'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45bcb044-d3c9-4009-9fc1-e65794faf9e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45bcb044-d3c9-4009-9fc1-e65794faf9e9")) {                    Plotly.newPlot(                        "45bcb044-d3c9-4009-9fc1-e65794faf9e9",                        [{"alignmentgroup":"True","hovertemplate":"State=Etobicoke York\u003cbr\u003eYear=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Etobicoke York","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Etobicoke York","offsetgroup":"Etobicoke York","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[337,363,337,269,241,283,269,265,211,198,263,223,232],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=North York\u003cbr\u003eYear=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North York","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"North York","offsetgroup":"North York","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[287,273,255,242,195,241,232,206,206,213,203,222,209],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=Scarborough\u003cbr\u003eYear=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Scarborough","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Scarborough","offsetgroup":"Scarborough","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[324,352,235,267,264,220,295,284,218,211,226,235,162],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State=Toronto and East York\u003cbr\u003eYear=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Toronto and East York","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Toronto and East York","offsetgroup":"Toronto and East York","orientation":"v","showlegend":true,"textposition":"auto","x":[2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[535,486,412,464,490,435,552,477,279,300,314,295,179],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale ...

# %%
# Group by light and visibility conditions and count the occurrences of collisions
light_visibility_counts = df.groupby(['LIGHT', 'VISIBILITY']).size().reset_index(name='Collision Count')

# Create a grouped bar plot using Plotly
fig = px.bar(light_visibility_counts, x='LIGHT', y='Collision Count', color='VISIBILITY',
             title='Comparison of Light and Visibility Conditions in Collisions',
             labels={'Collision Count': 'Collision Count', 'LIGHT': 'Light Condition', 'VISIBILITY': 'Visibility Condition'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16e8e583-9b83-4510-84d0-2a7d0001870f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16e8e583-9b83-4510-84d0-2a7d0001870f")) {                    Plotly.newPlot(                        "16e8e583-9b83-4510-84d0-2a7d0001870f",                        [{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Dawn","Dawn, artificial","Daylight","Daylight, artificial","Dusk","Dusk, artificial"],"xaxis":"x","y":[2655,1810,74,57,7888,89,165,131],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Drifting Snow\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Drifting Snow","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Drifting Snow","offsetgroup":"Drifting Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight","Dusk, artificial"],"xaxis":"x","y":[2,5,8,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Fog, Mist, Smoke, Dust\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fog, Mist, Smoke, Dust","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fog, Mist, Smoke, Dust","offsetgroup":"Fog, Mist, Smoke, Dust","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight"],"xaxis":"x","y":[18,11,15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Freezing Rain\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Freezing Rain","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Freezing Rain","offsetgroup":"Freezing Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight"],"xaxis":"x","y":[21,9,11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Other\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight","Dusk","Other"],"xaxis":"x","y":[37,4,47,1,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Rain\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rain","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Rain","offsetgroup":"Rain","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Dawn","Dawn, artificial","Daylight","Daylight, artificial","Dusk","Dusk, artificial"],"xaxis":"x","y":[555,371,24,21,576,10,35,21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Snow\u003cbr\u003eLight Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Snow","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Snow","offsetgroup":"Snow","orientation":"v","showlegend":true,"textposition":"auto","x":["Dark","Dark, artificial","Daylight","Dusk, artificial"],"xaxis":"x","y":[14 ...

# %%
# Filter out rows with null age values and get unique age groups
valid_age_groups = df.dropna(subset=['INVAGE'])['INVAGE'].unique()

# Group by age group, light conditions, and visibility conditions, and count the occurrences of collisions
age_light_visibility_counts = df.groupby(['INVAGE', 'LIGHT', 'VISIBILITY']).size().reset_index(name='Collision Count')

# Filter only the rows with valid age groups
age_light_visibility_counts = age_light_visibility_counts[age_light_visibility_counts['INVAGE'].isin(valid_age_groups)]

# Create a grouped bar plot using Plotly
fig = px.bar(age_light_visibility_counts, x='INVAGE', y='Collision Count', color='VISIBILITY',
             facet_col='LIGHT', facet_col_wrap=3,
             title='Comparison of Light and Visibility Conditions by Age Group',
             labels={'Collision Count': 'Collision Count', 'INVAGE': 'Age Group', 'VISIBILITY': 'Visibility Condition'},
             barmode='group')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5f5382ca-082e-4074-ab30-b7f1ce98159e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f5382ca-082e-4074-ab30-b7f1ce98159e")) {                    Plotly.newPlot(                        "5f5382ca-082e-4074-ab30-b7f1ce98159e",                        [{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear\u003cbr\u003eLIGHT=Dark\u003cbr\u003eAge Group=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":true,"textposition":"auto","x":["0 to 4","10 to 14","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","5 to 9","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","75 to 79","80 to 84","85 to 89","90 to 94","Over 95","unknown"],"xaxis":"x7","y":[13,22,188,308,305,189,162,168,144,17,139,125,82,54,41,29,15,16,2,4,632],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear\u003cbr\u003eLIGHT=Dark, artificial\u003cbr\u003eAge Group=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","10 to 14","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","5 to 9","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","75 to 79","80 to 84","85 to 89","90 to 94","Over 95","unknown"],"xaxis":"x8","y":[7,24,98,271,218,156,135,113,109,22,115,105,82,65,41,25,20,13,3,2,186],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear\u003cbr\u003eLIGHT=Dawn\u003cbr\u003eAge Group=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","unknown"],"xaxis":"x9","y":[4,5,4,8,4,9,6,3,8,3,3,1,16],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear\u003cbr\u003eLIGHT=Dawn, artificial\u003cbr\u003eAge Group=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","50 to 54","55 to 59","60 to 64","65 to 69","75 to 79","80 to 84","85 to 89","unknown"],"xaxis":"x4","y":[1,1,6,4,6,3,3,7,7,5,4,2,2,1,1,4],"yaxis":"y4","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibility Condition=Clear\u003cbr\u003eLIGHT=Daylight\u003cbr\u003eAge Group=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clear","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Clear","offsetgroup":"Clear","orientation":"v","showlegend":false,"textposition":"auto","x":["0 to 4","10 to 14","15 to 19","20 to 24","25 to 29","30 to 34","35 to 39","40 to 44","45 to 49","5 to 9","50 to 54","55 to 59","60 to 64","65 to 69","70 to 74","75 to 79","80 to 84","85 to 89","90 to 94","Over 95","unknown"],"xaxis":"x5","y":[99,109,281,550,568,528,617,580,577,100,609,485,395,303,268,238,179,133,41,5,1223],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Visibil ...

# %%
# Filter out rows with null age values and get unique age groups
valid_age_groups = df.dropna(subset=['INVAGE'])['INVAGE'].unique()

# Group by age group and count the occurrences of collisions
age_collision_counts = df['INVAGE'].value_counts().reset_index()
age_collision_counts.columns = ['Age Group', 'Collision Count']

# Filter only the rows with valid age groups
age_collision_counts = age_collision_counts[age_collision_counts['Age Group'].isin(valid_age_groups)]

# Create a bar plot using Plotly
fig = px.bar(age_collision_counts, x='Age Group', y='Collision Count',
             title='Collision Occurrences by Age Group',
             labels={'Collision Count': 'Collision Count', 'Age Group': 'Age Group'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0caa043e-2524-4518-9e9b-6ebdd3651a99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0caa043e-2524-4518-9e9b-6ebdd3651a99")) {                    Plotly.newPlot(                        "0caa043e-2524-4518-9e9b-6ebdd3651a99",                        [{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["unknown","20 to 24","25 to 29","30 to 34","40 to 44","35 to 39","50 to 54","45 to 49","55 to 59","60 to 64","15 to 19","65 to 69","70 to 74","75 to 79","80 to 84","10 to 14","85 to 89","5 to 9","0 to 4","90 to 94","Over 95"],"xaxis":"x","y":[2493,1363,1304,1072,1067,1062,1060,1031,870,680,679,527,426,354,264,193,184,166,142,52,11],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
# Group by injury type and count the occurrences of collisions
injury_collision_counts = df['INJURY'].value_counts().reset_index()
injury_collision_counts.columns = ['Injury Type', 'Collision Count']

# Create a bar plot using Plotly
fig = px.bar(injury_collision_counts, x='Injury Type', y='Collision Count',
             title='Collision Occurrences by Injury Type',
             labels={'Collision Count': 'Collision Count', 'Injury Type': 'Injury Type'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a56d096-69c0-457a-823e-9196ddcb289d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a56d096-69c0-457a-823e-9196ddcb289d")) {                    Plotly.newPlot(                        "3a56d096-69c0-457a-823e-9196ddcb289d",                        [{"alignmentgroup":"True","hovertemplate":"Injury Type=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["None","Major","Minor","Minimal","Fatal"],"xaxis":"x","y":[5583,4991,1183,936,701],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorba ...

# %%
# Group by initial direction of travel and count the occurrences of collisions
initdir_collision_counts = df['INITDIR'].value_counts().reset_index()
initdir_collision_counts.columns = ['Initial Direction', 'Collision Count']

# Create a bar plot using Plotly
fig = px.bar(initdir_collision_counts, x='Initial Direction', y='Collision Count',
             title='Collision Occurrences by Initial Direction of Travel',
             labels={'Collision Count': 'Collision Count', 'Initial Direction': 'Initial Direction'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="79827fc0-59fd-4d82-96e5-3d133cc4d691" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79827fc0-59fd-4d82-96e5-3d133cc4d691")) {                    Plotly.newPlot(                        "79827fc0-59fd-4d82-96e5-3d133cc4d691",                        [{"alignmentgroup":"True","hovertemplate":"Initial Direction=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["East","West","South","North","Unknown"],"xaxis":"x","y":[2650,2552,2487,2452,361],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"c ...

# %%
# Group by driver condition and count the occurrences of collisions
drivcond_collision_counts = df['DRIVCOND'].value_counts().reset_index()
drivcond_collision_counts.columns = ['Driver Condition', 'Collision Count']

# Create a bar plot using Plotly
fig = px.bar(drivcond_collision_counts, x='Driver Condition', y='Collision Count',
             title='Collision Occurrences by Driver Condition',
             labels={'Collision Count': 'Collision Count', 'Driver Condition': 'Driver Condition'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8f296a4f-2bbc-4742-bcf0-b81f26a4abac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f296a4f-2bbc-4742-bcf0-b81f26a4abac")) {                    Plotly.newPlot(                        "8f296a4f-2bbc-4742-bcf0-b81f26a4abac",                        [{"alignmentgroup":"True","hovertemplate":"Driver Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Normal","Inattentive","Unknown","Medical or Physical Disability","Had Been Drinking","Ability Impaired, Alcohol Over .08","Ability Impaired, Alcohol","Fatigue","Other","Ability Impaired, Drugs"],"xaxis":"x","y":[4795,1226,814,144,138,107,100,47,38,12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"}," ...

# %%
# Filter out rows with missing vehicle type
df_filtered = df.dropna(subset=['VEHTYPE'])

# Group by vehicle type and count the occurrences
collision_counts = df_filtered['VEHTYPE'].value_counts().reset_index()
collision_counts.columns = ['Vehicle Type', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(collision_counts, x='Vehicle Type', y='Collision Count',
             title='Total Collision Comparison by Vehicle Type',
             labels={'Vehicle Type': 'Vehicle Type', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eac22670-9803-47d7-8db7-ce15a329ab70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eac22670-9803-47d7-8db7-ce15a329ab70")) {                    Plotly.newPlot(                        "eac22670-9803-47d7-8db7-ce15a329ab70",                        [{"alignmentgroup":"True","hovertemplate":"Vehicle Type=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Automobile, Station Wagon","Other","Bicycle","Motorcycle","Municipal Transit Bus (TTC)","Truck - Open","Pick Up Truck","Passenger Van","Delivery Van","Truck - Closed (Blazer, etc)","Street Car","Truck - Dump","Taxi","Truck-Tractor","Moped","Bus (Other) (Go Bus, Gray Coach)","Truck (other)","Intercity Bus","Tow Truck","School Bus","Truck - Tank","Police Vehicle","Construction Equipment","Fire Vehicle","Off Road - 2 Wheels","Other Emergency Vehicle","Truck - Car Carrier"],"xaxis":"x","y":[6154,4743,635,505,225,170,131,100,54,42,32,28,27,25,22,11,10,8,5,4,4,3,2,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern": ...

# %%
# Filter out rows with missing pedestrian condition
df_filtered = df.dropna(subset=['PEDCOND'])

# Group by pedestrian condition and count the occurrences
collision_counts = df_filtered['PEDCOND'].value_counts().reset_index()
collision_counts.columns = ['Pedestrian Condition', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(collision_counts, x='Pedestrian Condition', y='Collision Count',
             title='Total Collision Comparison by Pedestrian Condition',
             labels={'Pedestrian Condition': 'Pedestrian Condition', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="dffdbd28-3c6c-477c-bb1c-8f608c489e5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dffdbd28-3c6c-477c-bb1c-8f608c489e5c")) {                    Plotly.newPlot(                        "dffdbd28-3c6c-477c-bb1c-8f608c489e5c",                        [{"alignmentgroup":"True","hovertemplate":"Pedestrian Condition=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Normal","Inattentive","Unknown","Had Been Drinking","Medical or Physical Disability","Other","Ability Impaired, Alcohol","Ability Impaired, Alcohol Over .80","Ability Impaired, Drugs","Fatigue"],"xaxis":"x","y":[1340,428,331,190,61,41,36,10,7,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"ma ...

# %%
# Count the occurrences of each factor
counts = {
    'Cyclist Involved': df['CYCLIST'].notnull().sum(),
    'Pedestrian Involved': df['PEDESTRIAN'].notnull().sum(),
    'Transit or City Vehicle Involved': df['TRSN_CITY_VEH'].notnull().sum(),
    'Passenger Involved': df['PASSENGER'].notnull().sum(),
    'Speeding Related': df['SPEEDING'].notnull().sum(),
    'Red Light Related': df['REDLIGHT'].notnull().sum(),
    'Alcohol Related': df['ALCOHOL'].notnull().sum(),
}

# Create a DataFrame from the counts
data = pd.DataFrame.from_dict(counts, orient='index', columns=['Count']).reset_index()

# Rename columns
data.columns = ['Factor', 'Count']

# Create a bar chart using Plotly Express
fig = px.bar(data, x='Factor', y='Count',
             title='Total Accidents and Involvement of Different Factors',
             labels={'Factor': 'Factor', 'Count': 'Count'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="aeb76aa2-e981-4a26-a03e-0aa1549c77c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeb76aa2-e981-4a26-a03e-0aa1549c77c4")) {                    Plotly.newPlot(                        "aeb76aa2-e981-4a26-a03e-0aa1549c77c4",                        [{"alignmentgroup":"True","hovertemplate":"Factor=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Cyclist Involved","Pedestrian Involved","Transit or City Vehicle Involved","Passenger Involved","Speeding Related","Red Light Related","Alcohol Related"],"xaxis":"x","y":[1578,5966,923,5633,1998,1275,672],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmod ...

# %%
# Count the occurrences of each factor
counts = {
    'Cyclist Involved': df['CYCLIST'].notnull().sum(),
    'Pedestrian Involved': df['PEDESTRIAN'].notnull().sum(),
    'Transit or City Vehicle Involved': df['TRSN_CITY_VEH'].notnull().sum(),
    'Passenger Involved': df['PASSENGER'].notnull().sum(),
    'Speeding Related': df['SPEEDING'].notnull().sum(),
    'Red Light Related': df['REDLIGHT'].notnull().sum(),
    'Alcohol Related': df['ALCOHOL'].notnull().sum(),
}

# Create a DataFrame from the counts
data = pd.DataFrame.from_dict(counts, orient='index', columns=['Count']).reset_index()

# Rename columns
data.columns = ['Factor', 'Count']

# Create a pie chart using Plotly Express
fig = px.pie(data, names='Factor', values='Count',
             title='Distribution of Accidents by Factor')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ec0e132f-7dcd-4932-be6f-2381a00956af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec0e132f-7dcd-4932-be6f-2381a00956af")) {                    Plotly.newPlot(                        "ec0e132f-7dcd-4932-be6f-2381a00956af",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Factor=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Cyclist Involved","Pedestrian Involved","Transit or City Vehicle Involved","Passenger Involved","Speeding Related","Red Light Related","Alcohol Related"],"legendgroup":"","name":"","showlegend":true,"values":[1578,5966,923,5633,1998,1275,672],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{" ...

# %%
# Filter out rows with missing involvement type
df_filtered = df.dropna(subset=['INVTYPE'])

# Group by involvement type and count the occurrences
collision_counts = df_filtered['INVTYPE'].value_counts().reset_index()
collision_counts.columns = ['Involvement Type', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(collision_counts, x='Involvement Type', y='Collision Count',
             title='Total Collisions by Involvement Type',
             labels={'Involvement Type': 'Involvement Type', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2d75d62a-b9a0-4ec5-8b04-785bc02c81f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d75d62a-b9a0-4ec5-8b04-785bc02c81f7")) {                    Plotly.newPlot(                        "2d75d62a-b9a0-4ec5-8b04-785bc02c81f7",                        [{"alignmentgroup":"True","hovertemplate":"Involvement Type=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Driver","Pedestrian","Passenger","Vehicle Owner","Cyclist","Motorcycle Driver","Truck Driver","Other Property Owner","Other","Moped Driver","Motorcycle Passenger","Driver - Not Hit","Wheelchair","In-Line Skater","Trailer Owner","Pedestrian - Not Hit","Witness","Cyclist Passenger"],"xaxis":"x","y":[6715,2476,2236,1636,639,505,280,257,157,27,24,16,12,5,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"co ...

# %%
# Filter out rows with missing district information
df_filtered = df.dropna(subset=['DISTRICT'])

# Group by district and count the occurrences
district_counts = df_filtered['DISTRICT'].value_counts().reset_index()
district_counts.columns = ['District', 'Collision Count']

# Create a bar chart using Plotly Express
fig = px.bar(district_counts, x='District', y='Collision Count',
             title='Total Collisions by District',
             labels={'District': 'District', 'Collision Count': 'Collision Count'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e5b68e9-1824-49df-aeb7-2e1ce2197baa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e5b68e9-1824-49df-aeb7-2e1ce2197baa")) {                    Plotly.newPlot(                        "3e5b68e9-1824-49df-aeb7-2e1ce2197baa",                        [{"alignmentgroup":"True","hovertemplate":"District=%{x}\u003cbr\u003eCollision Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Toronto and East York","Etobicoke York","Scarborough","North York"],"xaxis":"x","y":[5218,3491,3293,2984],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatterge ...

# %%
# Define a function to map dates to seasons
def get_season(date):
    month = date.month
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Autumn'
    else:
        return 'Winter'

# Convert the 'DATE' column to datetime format if it's not already
df['DATE'] = pd.to_datetime(df['DATE'])

# Apply the function to create a new column for seasons
df['SEASON'] = df['DATE'].apply(get_season)

# %%
# Filter out rows with missing season information
df_filtered = df.dropna(subset=['SEASON'])

# Group by season and count the occurrences
season_counts = df_filtered['SEASON'].value_counts().reset_index()
season_counts.columns = ['Season', 'Accident Count']

# Create a bar chart using Plotly Express
fig = px.bar(season_counts, x='Season', y='Accident Count',
             title='Accidents by Season',
             labels={'Season': 'Season', 'Accident Count': 'Number of Accidents'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="939ac363-f6cf-497a-972f-cc7a5a117fd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("939ac363-f6cf-497a-972f-cc7a5a117fd0")) {                    Plotly.newPlot(                        "939ac363-f6cf-497a-972f-cc7a5a117fd0",                        [{"alignmentgroup":"True","hovertemplate":"Season=%{x}\u003cbr\u003eNumber of Accidents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Summer","Autumn","Spring","Winter"],"xaxis":"x","y":[4463,4013,3437,3087],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outl ...

# %%
# Filter out rows with missing season and district information
df_filtered = df.dropna(subset=['SEASON', 'DISTRICT'])

# Group by season and district and count the occurrences
season_district_counts = df_filtered.groupby(['DISTRICT', 'SEASON']).size().reset_index(name='Accident Count')

# Create a grouped bar chart using Plotly Express
fig = px.bar(season_district_counts, x='DISTRICT', y='Accident Count', color='SEASON',
             title='Accidents by District and Season',
             labels={'DISTRICT': 'District', 'Accident Count': 'Number of Accidents'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="67deaa18-5854-4c0f-b7f8-05c600f6f2ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67deaa18-5854-4c0f-b7f8-05c600f6f2ae")) {                    Plotly.newPlot(                        "67deaa18-5854-4c0f-b7f8-05c600f6f2ae",                        [{"alignmentgroup":"True","hovertemplate":"SEASON=Autumn\u003cbr\u003eDistrict=%{x}\u003cbr\u003eNumber of Accidents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Autumn","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Autumn","offsetgroup":"Autumn","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[928,802,914,1361],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SEASON=Spring\u003cbr\u003eDistrict=%{x}\u003cbr\u003eNumber of Accidents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Spring","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Spring","offsetgroup":"Spring","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[813,692,709,1223],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SEASON=Summer\u003cbr\u003eDistrict=%{x}\u003cbr\u003eNumber of Accidents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Summer","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Summer","offsetgroup":"Summer","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[1018,892,932,1616],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"SEASON=Winter\u003cbr\u003eDistrict=%{x}\u003cbr\u003eNumber of Accidents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Winter","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Winter","offsetgroup":"Winter","orientation":"v","showlegend":true,"textposition":"auto","x":["Etobicoke York","North York","Scarborough","Toronto and East York"],"xaxis":"x","y":[732,598,738,1018],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777 ...

# %%
null_count = df.columns[df.isnull().any()]

print(null_count)
# Out:
# Index(['ACCNUM', 'STREET2', 'OFFSET', 'ROAD_CLASS', 'DISTRICT', 'LOCCOORD',
#        'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'RDSFCOND', 'INVTYPE', 'INJURY',
#        'FATAL_NO', 'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND',
#        'PEDTYPE', 'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND',
#        'PEDESTRIAN', 'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK',
#        'TRSN_CITY_VEH', 'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV',
#        'REDLIGHT', 'ALCOHOL', 'DISABILITY'],
#       dtype='object')

# %%
# First result: Total null values for each feature
null_counts = df.isnull().sum()
null_df = pd.DataFrame(null_counts, columns=["Missing Values"])

# Second result: Total unique values for each feature
unique_values = df.nunique().reset_index()
unique_values.columns = ["Feature", "Unique Values"]

# Combine the two DataFrames
combined_df = pd.merge(unique_values, null_df, left_on="Feature", right_index=True)

# Display the combined DataFrame
print(combined_df)
# Out:
#               Feature  Unique Values  Missing Values
# 0              INDEX_          15000               0
# 1              ACCNUM           3822            3698
# 2                YEAR             13               0
# 3                DATE           3082               0
# 4                TIME           1276               0
# 5             STREET1           1547               0
# 6             STREET2           2344            1343
# 7              OFFSET            339           13072
# 8          ROAD_CLASS              9             357
# 9            DISTRICT              4              14
# 10            WARDNUM             71               0
# 11           LATITUDE           3475               0
# 12          LONGITUDE           3901               0
# 13           LOCCOORD              7              90
# 14             ACCLOC              9            5450
# 15           TRAFFCTL             10              29
# 16         VISIBILITY              8              14
# 17              LIGHT              9               0
# 18           RDSFCOND              9              19
# 19            ACCLASS              2               0
# 20          IMPACTYPE             10               0
# 21            INVTYPE             18              10
# 22             INVAGE             21               0
# 23             INJURY              5            1606
# 24           FATAL_NO             78           14407
# 25            INITDIR              5            4498
# 26            VEHTYPE             27            2055
# 27          MANOEUVER             16            6514
# 28            DRIVACT             13            7575
# 29           DRIVCOND             10            7579
# 30            PEDTYPE             16           12540
# 31             PEDACT             15           12550
# 32            PEDCOND             10           12555
# 33         CYCLISTYPE             22           14365
# 34             CYCACT             11           14379
# 35            CYCCOND             10           14380
# 36         PEDESTRIAN              1            9034
# 37            CYCLIST              1           13422
# 38         AUTOMOBILE              1            1328
# 39         MOTORCYCLE              1           13838
# 40              TRUCK              1           14067
# 41      TRSN_CITY_VEH              1           14077
# 42          EMERG_VEH              1           14981
# 43          PASSENGER              1            9367
# 44           SPEEDING              1           13002
# 45            AG_DRIV              1            7304
# 46           REDLIGHT              1           13725
# 47            ALCOHOL              1           14328
# 48         DISABILITY              1           14580
# 49           HOOD_158            159               0
# 50  NEIGHBOURHOOD_158            159               0
# 51           HOOD_140            141               0
# 52  NEIGHBOURHOOD_140            141               0
# 53           DIVISION             17               0
# 54           ObjectId          15000               0
# 55             SEASON              4               0

# %%
df[df['FATAL_NO'] == df['FATAL_NO'].notnull()]
# Out:
#          INDEX_       ACCNUM  YEAR                      DATE  TIME  \
# 2070    5307141    1012986.0  2008 2008-01-05 05:00:00+00:00  1826
# 4997    5188679    1078551.0  2009 2009-01-01 05:00:00+00:00   259
# 5839    6253428    1146864.0  2010 2010-01-10 05:00:00+00:00   329
# 6743    6583562    1212031.0  2011 2011-01-11 05:00:00+00:00  1023
# 7327    7376307    1274722.0  2012 2012-01-12 05:00:00+00:00  2110
# 9830    7774165    1334928.0  2013 2013-01-10 05:00:00+00:00  1851
# 10256  80000020  141375171.0  2014 2014-01-19 05:00:00+00:00  2145
# 11303  80000105          NaN  2015 2015-01-11 05:00:00+00:00   353
# 12498  80497621          NaN  2016 2016-01-03 05:00:00+00:00  1915
# 13571  80609323          NaN  2017 2017-01-03 05:00:00+00:00   717
# 14385  80792372          NaN  2018 2018-01-01 05:00:00+00:00   125
#
#                    STREET1           STREET2          OFFSET      ROAD_CLASS  \
# 2070        EGLINTON AVE E         OSWEGO RD             NaN  Major Arterial
# 4997        EGLINTON AVE E       DANFORTH RD             NaN  Major Arterial
# 5839             KING ST E     PARLIAMENT ST             NaN  Major Arterial
# 6743            QUEEN ST W       BATHURST ST             NaN  Major Arterial
# 7327       FOREST GROVE DR          PAGE AVE             NaN           Local
# 9830       MORNINGSIDE AVE     OLD FINCH AVE             NaN  Minor Arterial
# 10256       EGLINTON AVE W  NORTHCLIFFE BLVD             NaN  Major Arterial
# 11303    477 BROADVIEW AVE               NaN             NaN  Minor Arterial
# 12498      1400 KENNEDY RD               NaN  196 m North of  Major Arterial
# 13571  LOWER SHERBOURNE ST     THE ESPLANADE             NaN  Minor Arterial
# 14385          BAYVIEW AVE        POTTERY RD      403 m N of  Major Arterial
#
#                     DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 2070             Scarborough     2120  43.737645 -79.243690  Intersection
# 4997             Scarborough     2120  43.737045 -79.246190  Intersection
# 5839   Toronto and East York       13  43.652745 -79.363190  Intersection
# 6743   Toronto and East York       10  43.647245 -79.403890  Intersection
# 7327              North York       17  43.779645 -79.378890     Mid-Block
# 9830             Scarborough       25  43.818743 -79.215091  Intersection
# 10256             North York      812  43.696250 -79.447673  Intersection
# 11303  Toronto and East York       14  43.669097 -79.352985     Mid-Block
# 12498            Scarborough       21  43.764498 -79.280681     Mid-Block
# 13571  Toronto and East York     1013  43.648974 -79.367259  Intersection
# 14385             North York     1115  43.692008 -79.361987     Mid-Block
#
#                  ACCLOC        TRAFFCTL VISIBILITY             LIGHT RDSFCOND  \
# 2070                NaN      No Control       Rain              Dark      Wet
# 4997    At Intersection  Traffic Signal      Clear              Dark      Wet
# 5839    At Intersection  Traffic Signal      Clear              Dark      Dry
# 6743    At Intersection      No Control      Clear          Daylight      Wet
# 7327                NaN      No Control      Clear  Dark, artificial      Wet
# 9830    At Intersection  Traffic Signal      Clear              Dark      Dry
# 10256   At Intersection  Traffic Signal      Clear  Dark, artificial      Wet
# 11303               NaN      No Control      Clear  Dark, artificial      Dry
# 12498  Non Intersection      No Control      Clear  Dark, artificial      Dry
# 13571   At Intersection  Traffic Signal       Rain              Dark      Wet
# 14385  Non Intersection      No Control      Clear  Dark, artificial      Dry
#
#       ACCLASS              IMPACTYPE     INVTYPE    INVAGE INJURY  FATAL_NO  \
# 2070    Fatal  Pedestrian Collisions  Pedestrian  30 to 34  Fatal       1.0
# 4997    Fatal  Pedestrian Collisions  Pedestrian  50 to 54  Fatal       1.0
# 5839    Fatal            Approaching      Driver  35 to 39  Fatal       1.0
# 6743    Fatal  Pedestrian Collisions  Pedestrian   unknown  Fatal       1.0
# 7327    Fatal  Pedestrian Collisions  Pedestrian  80 to 84  Fatal       1.0
# 9830    Fatal       Turning Movement      Driver  70 to 74  Fatal       1.0
# 10256   Fatal  Pedestrian Collisions  Pedestrian  35 to 39  Fatal       1.0
# 11303   Fatal              SMV Other      Driver  20 to 24  Fatal       1.0
# 12498   Fatal  Pedestrian Collisions  Pedestrian  35 to 39  Fatal       1.0
# 13571   Fatal  Pedestrian Collisions  Pedestrian  80 to 84  Fatal       1.0
# 14385   Fatal              SMV Other      Driver  35 to 39  Fatal       1.0
#
#        INITDIR                    VEHTYPE    MANOEUVER  \
# 2070     North                      Other          NaN
# 4997     North                      Other          NaN
# 5839      East  Automobile, Station Wagon  Going Ahead
# 6743     North                      Other          NaN
# 7327   Unknown                      Other          NaN
# 9830     North  Automobile, Station Wagon  Going Ahead
# 10256    South                        NaN          NaN
# 11303    South  Automobile, Station Wagon  Going Ahead
# 12498  Unknown                        NaN          NaN
# 13571     West                        NaN          NaN
# 14385    South  Automobile, Station Wagon  Going Ahead
#
#                             DRIVACT           DRIVCOND  \
# 2070                            NaN                NaN
# 4997                            NaN                NaN
# 5839                   Lost control  Had Been Drinking
# 6743                            NaN                NaN
# 7327                            NaN                NaN
# 9830      Disobeyed Traffic Control            Unknown
# 10256                           NaN                NaN
# 11303                  Lost control            Unknown
# 12498                           NaN                NaN
# 13571                           NaN                NaN
# 14385  Speed too Fast For Condition            Unknown
#
#                                                  PEDTYPE  \
# 2070   Vehicle is going straight thru inter.while ped...
# 4997   Vehicle is going straight thru inter.while ped...
# 5839                                                 NaN
# 6743   Pedestrian involved in a collision with transi...
# 7327            Vehicle is reversing and hits pedestrian
# 9830                                                 NaN
# 10256  Vehicle is going straight thru inter.while ped...
# 11303                                                NaN
# 12498                        Pedestrian hit at mid-block
# 13571  Vehicle is going straight thru inter.while ped...
# 14385                                                NaN
#
#                               PEDACT                             PEDCOND  \
# 2070    Crossing, no Traffic Control                              Normal
# 4997   Crossing without right of way  Ability Impaired, Alcohol Over .80
# 5839                             NaN                                 NaN
# 6743    Crossing, no Traffic Control                             Unknown
# 7327                           Other      Medical or Physical Disability
# 9830                             NaN                                 NaN
# 10256  Crossing without right of way                             Unknown
# 11303                            NaN                                 NaN
# 12498  Crossing without right of way                   Had Been Drinking
# 13571  Crossing without right of way                              Normal
# 14385                            NaN                                 NaN
#
#       CYCLISTYPE CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE  \
# 2070         NaN    NaN     NaN        Yes     NaN        Yes        NaN
# 4997         NaN    NaN     NaN        Yes     NaN        Yes        NaN
# 5839         NaN    NaN     NaN        NaN     NaN        Yes        NaN
# 6743         NaN    NaN     NaN        Yes     NaN        NaN        NaN
# 7327         NaN    NaN     NaN        Yes     NaN        Yes        NaN
# 9830         NaN    NaN     NaN        NaN     NaN        Yes        NaN
# 10256        NaN    NaN     NaN        Yes     NaN        Yes        NaN
# 11303        NaN    NaN     NaN        NaN     NaN        Yes        NaN
# 12498        NaN    NaN     NaN        Yes     NaN        Yes        NaN
# 13571        NaN    NaN     NaN        Yes     NaN        Yes        NaN
# 14385        NaN    NaN     NaN        NaN     NaN        Yes        NaN
#
#       TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT  \
# 2070    NaN           NaN       NaN       NaN      NaN     NaN      NaN
# 4997    NaN           NaN       NaN       NaN      NaN     NaN      NaN
# 5839    NaN           NaN       NaN       NaN      Yes     Yes      NaN
# 6743    NaN           Yes       NaN       NaN      NaN     NaN      NaN
# 7327    NaN           NaN       NaN       NaN      NaN     NaN      NaN
# 9830    NaN           Yes       NaN       NaN      Yes     Yes      Yes
# 10256   NaN           NaN       NaN       NaN      NaN     NaN      NaN
# 11303   NaN           NaN       NaN       NaN      Yes     Yes      NaN
# 12498   NaN           NaN       NaN       Yes      NaN     Yes      NaN
# 13571   NaN           NaN       NaN       NaN      NaN     NaN      NaN
# 14385   NaN           NaN       NaN       NaN      Yes     Yes      NaN
#
#       ALCOHOL DISABILITY HOOD_158                      NEIGHBOURHOOD_158  \
# 2070      NaN        NaN      138                          Eglinton East
# 4997      NaN        NaN      138                          Eglinton East
# 5839      NaN        NaN       73                              Moss Park
# 6743      NaN        NaN       78                   Kensington-Chinatown
# 7327      NaN        NaN       52                        Bayview Village
# 9830      NaN        NaN      146                           Malvern East
# 10256     NaN        NaN      107                        Oakwood Village
# 11303     NaN        NaN       68                        North Riverdale
# 12498     NaN        NaN      126                            Dorset Park
# 13571     NaN        NaN      166  St Lawrence-East Bayfront-The Islands
# 14385     NaN        NaN       56                     Leaside-Bennington
#
#       HOOD_140                       NEIGHBOURHOOD_140 DIVISION  ObjectId  \
# 2070       138                     Eglinton East (138)      D43      2071
# 4997       138                     Eglinton East (138)      D43      4998
# 5839        73                          Moss Park (73)      D51      5840
# 6743        78               Kensington-Chinatown (78)      D14      6744
# 7327        52                    Bayview Village (52)      D33      7328
# 9830       132                           Malvern (132)      D42      9831
# 10256      107                   Oakwood Village (107)      D13     10257
# 11303       68                    North Riverdale (68)      D55     11304
# 12498      126                       Dorset Park (126)      D41     12499
# 13571       77  Waterfront Communities-The Island (77)      D51     13572
# 14385       56                 Leaside-Bennington (56)      D53     14386
#
#        SEASON
# 2070   Winter
# 4997   Winter
# 5839   Winter
# 6743   Winter
# 7327   Winter
# 9830   Winter
# 10256  Winter
# 11303  Winter
# 12498  Winter
# 13571  Winter
# 14385  Winter

# %%
df[df["CYCACT"] == df['CYCACT'].unique]
# Out:
# Empty DataFrame
# Columns: [INDEX_, ACCNUM, YEAR, DATE, TIME, STREET1, STREET2, OFFSET, ROAD_CLASS, DISTRICT, WARDNUM, LATITUDE, LONGITUDE, LOCCOORD, ACCLOC, TRAFFCTL, VISIBILITY, LIGHT, RDSFCOND, ACCLASS, IMPACTYPE, INVTYPE, INVAGE, INJURY, FATAL_NO, INITDIR, VEHTYPE, MANOEUVER, DRIVACT, DRIVCOND, PEDTYPE, PEDACT, PEDCOND, CYCLISTYPE, CYCACT, CYCCOND, PEDESTRIAN, CYCLIST, AUTOMOBILE, MOTORCYCLE, TRUCK, TRSN_CITY_VEH, EMERG_VEH, PASSENGER, SPEEDING, AG_DRIV, REDLIGHT, ALCOHOL, DISABILITY, HOOD_158, NEIGHBOURHOOD_158, HOOD_140, NEIGHBOURHOOD_140, DIVISION, ObjectId, SEASON]
# Index: []

# %%
df['CYCACT'].unique()
# Out:
# array([nan, 'Failed to Yield Right of Way', 'Driving Properly', 'Other',
#        'Improper Passing', 'Disobeyed Traffic Control', 'Lost control',
#        'Improper Turn', 'Improper Lane Change', 'Following too Close',
#        'Speed too Fast For Condition', 'Wrong Way on One Way Road'],
#       dtype=object)

# %%
# Get a specific value from the "MOTORCYCLE" column
motorcycle_value = df.at[0, "MOTORCYCLE"]

# Convert the value to a string
str_motorcycle_value = str(motorcycle_value)

# Display the resulting string
print(str_motorcycle_value)
# Out:
# nan

# %%
df.dtypes
# Out:
# INDEX_                             int64
# ACCNUM                           float64
# YEAR                               int64
# DATE                 datetime64[ns, UTC]
# TIME                               int64
# STREET1                           object
# STREET2                           object
# OFFSET                            object
# ROAD_CLASS                        object
# DISTRICT                          object
# WARDNUM                            int64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCCOORD                          object
# ACCLOC                            object
# TRAFFCTL                          object
# VISIBILITY                        object
# LIGHT                             object
# RDSFCOND                          object
# ACCLASS                           object
# IMPACTYPE                         object
# INVTYPE                           object
# INVAGE                            object
# INJURY                            object
# FATAL_NO                         float64
# INITDIR                           object
# VEHTYPE                           object
# MANOEUVER                         object
# DRIVACT                           object
# DRIVCOND                          object
# PEDTYPE                           object
# PEDACT                            object
# PEDCOND                           object
# CYCLISTYPE                        object
# CYCACT                            object
# CYCCOND                           object
# PEDESTRIAN                        object
# CYCLIST                           object
# AUTOMOBILE                        object
# MOTORCYCLE                        object
# TRUCK                             object
# TRSN_CITY_VEH                     object
# EMERG_VEH                         object
# PASSENGER                         object
# SPEEDING                          object
# AG_DRIV                           object
# REDLIGHT                          object
# ALCOHOL                           object
# DISABILITY                        object
# HOOD_158                          object
# NEIGHBOURHOOD_158                 object
# HOOD_140                          object
# NEIGHBOURHOOD_140                 object
# DIVISION                          object
# ObjectId                           int64
# SEASON                            object
# dtype: object

# %%
df["YEAR"]
# Out:
# 0        2006
# 1        2006
# 2        2006
# 3        2006
# 4        2006
#          ...
# 14995    2018
# 14996    2018
# 14997    2018
# 14998    2018
# 14999    2018
# Name: YEAR, Length: 15000, dtype: int64

# %%
df["TIME"].isna().sum()
# Out:
# 0

# %%
df["TIME"].isna().sum()
# Out:
# 0

# %%
df["DATE"].isna().sum()
# Out:
# 0

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# Accessing year, month, and day components
df['Year'] = df['DATE'].dt.year
df['Month'] = df['DATE'].dt.month
df['Day'] = df['DATE'].dt.day

# Displaying the updated DataFrame
print(df[['DATE', 'Year', 'Month', 'Day']].head())
# Out:
#                        DATE  Year  Month  Day
# 0 2006-03-11 05:00:00+00:00  2006      3   11
# 1 2006-03-11 05:00:00+00:00  2006      3   11
# 2 2006-03-11 05:00:00+00:00  2006      3   11
# 3 2006-01-01 05:00:00+00:00  2006      1    1
# 4 2006-03-11 05:00:00+00:00  2006      3   11

# %%
first_row = df.iloc[0]
second_row = df.iloc[1]

comparison = (first_row == second_row)
# print(comparison)

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# Print the comparison DataFrame
print(comparison)

# true_count = comparison.value_counts()[True]
# false_count = comparison.value_counts()[False]

# print("Number of True values:", true_count)
# print("Number of False values:", false_count)
# Out:
# INDEX_               False
# ACCNUM                True
# YEAR                  True
# DATE                  True
# TIME                  True
# STREET1               True
# STREET2               True
# OFFSET               False
# ROAD_CLASS            True
# DISTRICT              True
# WARDNUM               True
# LATITUDE              True
# LONGITUDE             True
# LOCCOORD              True
# ACCLOC                True
# TRAFFCTL              True
# VISIBILITY            True
# LIGHT                 True
# RDSFCOND              True
# ACCLASS               True
# IMPACTYPE             True
# INVTYPE              False
# INVAGE               False
# INJURY               False
# FATAL_NO             False
# INITDIR              False
# VEHTYPE              False
# MANOEUVER            False
# DRIVACT              False
# DRIVCOND             False
# PEDTYPE              False
# PEDACT               False
# PEDCOND              False
# CYCLISTYPE           False
# CYCACT               False
# CYCCOND              False
# PEDESTRIAN            True
# CYCLIST              False
# AUTOMOBILE            True
# MOTORCYCLE           False
# TRUCK                False
# TRSN_CITY_VEH        False
# EMERG_VEH            False
# PASSENGER            False
# SPEEDING             False
# AG_DRIV               True
# REDLIGHT             False
# ALCOHOL              False
# DISABILITY           False
# HOOD_158              True
# NEIGHBOURHOOD_158     True
# HOOD_140              True
# NEIGHBOURHOOD_140     True
# DIVISION              True
# ObjectId             False
# SEASON                True
# Year                  True
# Month                 True
# Day                   True
# dtype: bool

# %%
df.head(30)
# Out:
#      INDEX_    ACCNUM  YEAR                      DATE  TIME  \
# 0   3387730  892658.0  2006 2006-03-11 05:00:00+00:00   852
# 1   3387731  892658.0  2006 2006-03-11 05:00:00+00:00   852
# 2   3388101  892810.0  2006 2006-03-11 05:00:00+00:00   915
# 3   3389067  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 4   3388102  892810.0  2006 2006-03-11 05:00:00+00:00   915
# 5   3387793  892682.0  2006 2006-03-12 05:00:00+00:00   240
# 6   3389068  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 7   3389069  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 8   3387794  892682.0  2006 2006-03-12 05:00:00+00:00   240
# 9   3387795  892682.0  2006 2006-03-12 05:00:00+00:00   240
# 10  3389070  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 11  3389071  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 12  3388371  892913.0  2006 2006-03-12 05:00:00+00:00  1903
# 13  3442993  913296.0  2006 2006-06-25 04:00:00+00:00  2040
# 14  3389072  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 15  3388372  892913.0  2006 2006-03-12 05:00:00+00:00  1903
# 16  3437675  911336.0  2006 2006-06-28 04:00:00+00:00  1000
# 17  3389073  893184.0  2006 2006-01-01 05:00:00+00:00   236
# 18  3389258  893251.0  2006 2006-03-15 05:00:00+00:00  1535
# 19  3437676  911336.0  2006 2006-06-28 04:00:00+00:00  1000
# 20  3437677  911336.0  2006 2006-06-28 04:00:00+00:00  1000
# 21  3448305  915319.0  2006 2006-06-28 04:00:00+00:00  1357
# 22  3448306  915319.0  2006 2006-06-28 04:00:00+00:00  1357
# 23  3448307  915319.0  2006 2006-06-28 04:00:00+00:00  1357
# 24  3448249  915300.0  2006 2006-06-28 04:00:00+00:00  1730
# 25  3448250  915300.0  2006 2006-06-28 04:00:00+00:00  1730
# 26  3448251  915300.0  2006 2006-06-28 04:00:00+00:00  1730
# 27  3448252  915300.0  2006 2006-06-28 04:00:00+00:00  1730
# 28  3448253  915300.0  2006 2006-06-28 04:00:00+00:00  1730
# 29  3438192  911521.0  2006 2006-06-29 04:00:00+00:00   954
#
#                 STREET1           STREET2 OFFSET      ROAD_CLASS  \
# 0            BLOOR ST W       DUNDAS ST W    NaN  Major Arterial
# 1            BLOOR ST W       DUNDAS ST W    NaN  Major Arterial
# 2       MORNINGSIDE AVE    SHEPPARD AVE E    NaN  Major Arterial
# 3          WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 4       MORNINGSIDE AVE    SHEPPARD AVE E    NaN  Major Arterial
# 5        EGLINTON AVE E  COMMONWEALTH AVE    NaN  Major Arterial
# 6          WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 7          WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 8        EGLINTON AVE E  COMMONWEALTH AVE    NaN  Major Arterial
# 9        EGLINTON AVE E  COMMONWEALTH AVE    NaN  Major Arterial
# 10         WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 11         WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 12        OSSINGTON AVE       DUNDAS ST W    NaN  Major Arterial
# 13  29 BLAIR ATHOL Cres               NaN    NaN           Local
# 14         WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 15        OSSINGTON AVE       DUNDAS ST W    NaN  Major Arterial
# 16        BIRCHMOUNT RD         MODERN RD    NaN  Major Arterial
# 17         WOODBINE AVE       O CONNOR DR    NaN  Major Arterial
# 18        ISLINGTON AVE          DIXON RD    NaN  Major Arterial
# 19        BIRCHMOUNT RD         MODERN RD    NaN  Major Arterial
# 20        BIRCHMOUNT RD         MODERN RD    NaN  Major Arterial
# 21            KING ST W           YORK ST    NaN  Major Arterial
# 22            KING ST W           YORK ST    NaN  Major Arterial
# 23            KING ST W           YORK ST    NaN  Major Arterial
# 24       EGLINTON AVE W      GLENHAVEN ST    NaN  Major Arterial
# 25       EGLINTON AVE W      GLENHAVEN ST    NaN  Major Arterial
# 26       EGLINTON AVE W      GLENHAVEN ST    NaN  Major Arterial
# 27       EGLINTON AVE W      GLENHAVEN ST    NaN  Major Arterial
# 28       EGLINTON AVE W      GLENHAVEN ST    NaN  Major Arterial
# 29            WESTON RD        JASPER AVE    NaN  Minor Arterial
#
#                  DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 0   Toronto and East York        4  43.656345 -79.452490  Intersection
# 1   Toronto and East York        4  43.656345 -79.452490  Intersection
# 2             Scarborough       25  43.801943 -79.199786  Intersection
# 3   Toronto and East York       19  43.699595 -79.318797  Intersection
# 4             Scarborough       25  43.801943 -79.199786  Intersection
# 5             Scarborough     2120  43.734945 -79.256190     Mid-Block
# 6   Toronto and East York       19  43.699595 -79.318797  Intersection
# 7   Toronto and East York       19  43.699595 -79.318797  Intersection
# 8             Scarborough     2120  43.734945 -79.256190     Mid-Block
# 9             Scarborough     2120  43.734945 -79.256190     Mid-Block
# 10  Toronto and East York       19  43.699595 -79.318797  Intersection
# 11  Toronto and East York       19  43.699595 -79.318797  Intersection
# 12  Toronto and East York    91110  43.649345 -79.420790  Intersection
# 13         Etobicoke York        2  43.667245 -79.544690     Mid-Block
# 14  Toronto and East York       19  43.699595 -79.318797  Intersection
# 15  Toronto and East York    91110  43.649345 -79.420790  Intersection
# 16            Scarborough       21  43.744045 -79.283490  Intersection
# 17  Toronto and East York       19  43.699595 -79.318797  Intersection
# 18         Etobicoke York       12  43.697045 -79.546690  Intersection
# 19            Scarborough       21  43.744045 -79.283490  Intersection
# 20            Scarborough       21  43.744045 -79.283490  Intersection
# 21  Toronto and East York       10  43.648545 -79.380890     Mid-Block
# 22  Toronto and East York       10  43.648545 -79.380890     Mid-Block
# 23  Toronto and East York       10  43.648545 -79.380890     Mid-Block
# 24         Etobicoke York        5  43.691345 -79.469690  Intersection
# 25         Etobicoke York        5  43.691345 -79.469690  Intersection
# 26         Etobicoke York        5  43.691345 -79.469690  Intersection
# 27         Etobicoke York        5  43.691345 -79.469690  Intersection
# 28         Etobicoke York        5  43.691345 -79.469690  Intersection
# 29         Etobicoke York        5  43.683745 -79.482490  Intersection
#
#                   ACCLOC        TRAFFCTL VISIBILITY     LIGHT RDSFCOND  \
# 0        At Intersection  Traffic Signal      Clear  Daylight      Dry
# 1        At Intersection  Traffic Signal      Clear  Daylight      Dry
# 2        At Intersection  Traffic Signal      Clear  Daylight      Dry
# 3   Intersection Related      No Control      Clear      Dark      Wet
# 4        At Intersection  Traffic Signal      Clear  Daylight      Dry
# 5                    NaN      No Control      Clear      Dark      Dry
# 6   Intersection Related      No Control      Clear      Dark      Wet
# 7   Intersection Related      No Control      Clear      Dark      Wet
# 8                    NaN      No Control      Clear      Dark      Dry
# 9                    NaN      No Control      Clear      Dark      Dry
# 10  Intersection Related      No Control      Clear      Dark      Wet
# 11  Intersection Related      No Control      Clear      Dark      Wet
# 12       At Intersection  Traffic Signal      Clear      Dark      Dry
# 13                   NaN      No Control      Clear      Dusk      Dry
# 14  Intersection Related      No Control      Clear      Dark      Wet
# 15       At Intersection  Traffic Signal      Clear      Dark      Dry
# 16                   NaN       Stop Sign      Clear  Daylight      Dry
# 17  Intersection Related      No Control      Clear      Dark      Wet
# 18       At Intersection  Traffic Signal      Clear  Daylight      Dry
# 19                   NaN       Stop Sign      Clear  Daylight      Dry
# 20                   NaN       Stop Sign      Clear  Daylight      Dry
# 21                   NaN      No Control      Clear  Daylight      Dry
# 22                   NaN      No Control      Clear  Daylight      Dry
# 23                   NaN      No Control      Clear  Daylight      Dry
# 24       At Intersection       Stop Sign       Rain  Daylight      Wet
# 25       At Intersection       Stop Sign       Rain  Daylight      Wet
# 26       At Intersection       Stop Sign       Rain  Daylight      Wet
# 27       At Intersection       Stop Sign       Rain  Daylight      Wet
# 28       At Intersection       Stop Sign       Rain  Daylight      Wet
# 29                   NaN      No Control      Clear  Daylight      Dry
#
#              ACCLASS              IMPACTYPE            INVTYPE    INVAGE  \
# 0              Fatal  Pedestrian Collisions             Driver   unknown
# 1              Fatal  Pedestrian Collisions         Pedestrian  65 to 69
# 2              Fatal       Turning Movement  Motorcycle Driver  45 to 49
# 3   Non-Fatal Injury            Approaching          Passenger  50 to 54
# 4              Fatal       Turning Movement             Driver   unknown
# 5              Fatal  Pedestrian Collisions             Driver  25 to 29
# 6   Non-Fatal Injury            Approaching          Passenger  15 to 19
# 7   Non-Fatal Injury            Approaching             Driver  55 to 59
# 8              Fatal  Pedestrian Collisions         Pedestrian  30 to 34
# 9              Fatal  Pedestrian Collisions         Pedestrian  40 to 44
# 10  Non-Fatal Injury            Approaching          Passenger  20 to 24
# 11  Non-Fatal Injury            Approaching          Passenger  15 to 19
# 12  Non-Fatal Injury  Pedestrian Collisions             Driver  30 to 34
# 13  Non-Fatal Injury                  Other          Passenger  15 to 19
# 14  Non-Fatal Injury            Approaching          Passenger  20 to 24
# 15  Non-Fatal Injury  Pedestrian Collisions         Pedestrian  25 to 29
# 16  Non-Fatal Injury     Cyclist Collisions      Vehicle Owner   unknown
# 17  Non-Fatal Injury            Approaching      Vehicle Owner   unknown
# 18             Fatal  Pedestrian Collisions             Driver  40 to 44
# 19  Non-Fatal Injury     Cyclist Collisions             Driver  45 to 49
# 20  Non-Fatal Injury     Cyclist Collisions            Cyclist  30 to 34
# 21  Non-Fatal Injury  Pedestrian Collisions         Pedestrian  35 to 39
# 22  Non-Fatal Injury  Pedestrian Collisions      Vehicle Owner   unknown
# 23  Non-Fatal Injury  Pedestrian Collisions             Driver  35 to 39
# 24  Non-Fatal Injury                  Angle      Vehicle Owner   unknown
# 25  Non-Fatal Injury                  Angle       Truck Driver  40 to 44
# 26  Non-Fatal Injury                  Angle      Vehicle Owner   unknown
# 27  Non-Fatal Injury                  Angle          Passenger  20 to 24
# 28  Non-Fatal Injury                  Angle             Driver  20 to 24
# 29  Non-Fatal Injury     Cyclist Collisions      Vehicle Owner   unknown
#
#      INJURY  FATAL_NO INITDIR                      VEHTYPE      MANOEUVER  \
# 0      None       NaN   South    Automobile, Station Wagon   Turning Left
# 1     Fatal       NaN   North                        Other            NaN
# 2     Fatal       NaN    East                   Motorcycle  Turning Right
# 3     Major       NaN     NaN                          NaN            NaN
# 4      None       NaN   South    Automobile, Station Wagon    Going Ahead
# 5      None       NaN    West    Automobile, Station Wagon    Going Ahead
# 6     Minor       NaN     NaN                          NaN            NaN
# 7     Minor       NaN   North    Automobile, Station Wagon    Going Ahead
# 8     Minor       NaN   South                        Other            NaN
# 9     Fatal       NaN   South                        Other            NaN
# 10    Minor       NaN     NaN                          NaN            NaN
# 11    Minor       NaN     NaN                          NaN            NaN
# 12     None       NaN    East    Automobile, Station Wagon   Turning Left
# 13    Major       NaN     NaN                        Other            NaN
# 14    Minor       NaN     NaN                          NaN            NaN
# 15    Major       NaN    West                        Other            NaN
# 16      NaN       NaN     NaN                        Other            NaN
# 17      NaN       NaN     NaN                          NaN            NaN
# 18     None       NaN    East    Automobile, Station Wagon    Going Ahead
# 19     None       NaN   South    Automobile, Station Wagon    Going Ahead
# 20    Major       NaN    East                      Bicycle  Turning Right
# 21    Major       NaN   South                        Other            NaN
# 22      NaN       NaN     NaN                        Other            NaN
# 23     None       NaN    West  Municipal Transit Bus (TTC)    Going Ahead
# 24     None       NaN     NaN                        Other            NaN
# 25  Minimal       NaN   South                 Truck - Open        Stopped
# 26     None       NaN     NaN                        Other            NaN
# 27    Major       NaN     NaN                        Other            NaN
# 28  Minimal       NaN    West    Automobile, Station Wagon    Going Ahead
# 29      NaN       NaN     NaN                        Other            NaN
#
#                          DRIVACT                            DRIVCOND  \
# 0   Failed to Yield Right of Way                             Unknown
# 1                            NaN                                 NaN
# 2      Disobeyed Traffic Control                             Unknown
# 3                            NaN                                 NaN
# 4               Driving Properly                             Unknown
# 5                          Other           Ability Impaired, Alcohol
# 6                            NaN                                 NaN
# 7               Driving Properly                              Normal
# 8                            NaN                                 NaN
# 9                            NaN                                 NaN
# 10                           NaN                                 NaN
# 11                           NaN                                 NaN
# 12  Failed to Yield Right of Way  Ability Impaired, Alcohol Over .08
# 13                           NaN                                 NaN
# 14                           NaN                                 NaN
# 15                           NaN                                 NaN
# 16                           NaN                                 NaN
# 17                           NaN                                 NaN
# 18              Driving Properly                              Normal
# 19              Driving Properly                              Normal
# 20                           NaN                                 NaN
# 21                           NaN                                 NaN
# 22                           NaN                                 NaN
# 23              Driving Properly                              Normal
# 24                           NaN                                 NaN
# 25              Driving Properly                              Normal
# 26                           NaN                                 NaN
# 27                           NaN                                 NaN
# 28              Improper Passing                              Normal
# 29                           NaN                                 NaN
#
#                                               PEDTYPE  \
# 0                                                 NaN
# 1   Vehicle turns left while ped crosses with ROW ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                         Pedestrian hit at mid-block
# 9                         Pedestrian hit at mid-block
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Vehicle turns left while ped crosses with ROW ...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Pedestrian involved in a collision with transi...
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                           PEDACT  PEDCOND  \
# 0                            NaN      NaN
# 1     Crossing with right of way  Unknown
# 2                            NaN      NaN
# 3                            NaN      NaN
# 4                            NaN      NaN
# 5                            NaN      NaN
# 6                            NaN      NaN
# 7                            NaN      NaN
# 8   Crossing, no Traffic Control   Normal
# 9   Crossing, no Traffic Control   Normal
# 10                           NaN      NaN
# 11                           NaN      NaN
# 12                           NaN      NaN
# 13                           NaN      NaN
# 14                           NaN      NaN
# 15    Crossing with right of way   Normal
# 16                           NaN      NaN
# 17                           NaN      NaN
# 18                           NaN      NaN
# 19                           NaN      NaN
# 20                           NaN      NaN
# 21  Crossing, no Traffic Control  Unknown
# 22                           NaN      NaN
# 23                           NaN      NaN
# 24                           NaN      NaN
# 25                           NaN      NaN
# 26                           NaN      NaN
# 27                           NaN      NaN
# 28                           NaN      NaN
# 29                           NaN      NaN
#
#                                    CYCLISTYPE                        CYCACT  \
# 0                                         NaN                           NaN
# 1                                         NaN                           NaN
# 2                                         NaN                           NaN
# 3                                         NaN                           NaN
# 4                                         NaN                           NaN
# 5                                         NaN                           NaN
# 6                                         NaN                           NaN
# 7                                         NaN                           NaN
# 8                                         NaN                           NaN
# 9                                         NaN                           NaN
# 10                                        NaN                           NaN
# 11                                        NaN                           NaN
# 12                                        NaN                           NaN
# 13                                        NaN                           NaN
# 14                                        NaN                           NaN
# 15                                        NaN                           NaN
# 16                                        NaN                           NaN
# 17                                        NaN                           NaN
# 18                                        NaN                           NaN
# 19                                        NaN                           NaN
# 20  Cyclist turns right across motorists path  Failed to Yield Right of Way
# 21                                        NaN                           NaN
# 22                                        NaN                           NaN
# 23                                        NaN                           NaN
# 24                                        NaN                           NaN
# 25                                        NaN                           NaN
# 26                                        NaN                           NaN
# 27                                        NaN                           NaN
# 28                                        NaN                           NaN
# 29                                        NaN                           NaN
#
#         CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH  \
# 0           NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 1           NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 2           NaN        NaN     NaN        Yes        Yes   NaN           NaN
# 3           NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 4           NaN        NaN     NaN        Yes        Yes   NaN           NaN
# 5           NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 6           NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 7           NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 8           NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 9           NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 10          NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 11          NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 12          NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 13          NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 14          NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 15          NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 16          NaN        NaN     Yes        Yes        NaN   NaN           NaN
# 17          NaN        NaN     NaN        Yes        NaN   NaN           NaN
# 18          NaN        Yes     NaN        Yes        NaN   NaN           NaN
# 19          NaN        NaN     Yes        Yes        NaN   NaN           NaN
# 20  Inattentive        NaN     Yes        Yes        NaN   NaN           NaN
# 21          NaN        Yes     NaN        NaN        NaN   NaN           Yes
# 22          NaN        Yes     NaN        NaN        NaN   NaN           Yes
# 23          NaN        Yes     NaN        NaN        NaN   NaN           Yes
# 24          NaN        NaN     NaN        Yes        NaN   Yes           NaN
# 25          NaN        NaN     NaN        Yes        NaN   Yes           NaN
# 26          NaN        NaN     NaN        Yes        NaN   Yes           NaN
# 27          NaN        NaN     NaN        Yes        NaN   Yes           NaN
# 28          NaN        NaN     NaN        Yes        NaN   Yes           NaN
# 29          NaN        NaN     Yes        Yes        NaN   NaN           NaN
#
#    EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 0        NaN       NaN      NaN     Yes      NaN     NaN        NaN       88
# 1        NaN       NaN      NaN     Yes      NaN     NaN        NaN       88
# 2        NaN       NaN      NaN     Yes      Yes     NaN        NaN      146
# 3        NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 4        NaN       NaN      NaN     Yes      Yes     NaN        NaN      146
# 5        NaN       NaN      NaN     NaN      NaN     Yes        NaN      124
# 6        NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 7        NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 8        NaN       NaN      NaN     NaN      NaN     Yes        NaN      124
# 9        NaN       NaN      NaN     NaN      NaN     Yes        NaN      124
# 10       NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 11       NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 12       NaN       NaN      NaN     Yes      NaN     Yes        NaN       81
# 13       NaN       Yes      NaN     NaN      NaN     NaN        NaN       10
# 14       NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 15       NaN       NaN      NaN     Yes      NaN     Yes        NaN       81
# 16       NaN       NaN      NaN     NaN      NaN     NaN        NaN      119
# 17       NaN       Yes      Yes     Yes      NaN     Yes        NaN       60
# 18       NaN       NaN      NaN     NaN      NaN     NaN        NaN        6
# 19       NaN       NaN      NaN     NaN      NaN     NaN        NaN      119
# 20       NaN       NaN      NaN     NaN      NaN     NaN        NaN      119
# 21       NaN       NaN      NaN     NaN      NaN     NaN        NaN      170
# 22       NaN       NaN      NaN     NaN      NaN     NaN        NaN      170
# 23       NaN       NaN      NaN     NaN      NaN     NaN        NaN      170
# 24       NaN       Yes      NaN     Yes      NaN     NaN        NaN      110
# 25       NaN       Yes      NaN     Yes      NaN     NaN        NaN      110
# 26       NaN       Yes      NaN     Yes      NaN     NaN        NaN      110
# 27       NaN       Yes      NaN     Yes      NaN     NaN        NaN      110
# 28       NaN       Yes      NaN     Yes      NaN     NaN        NaN      110
# 29       NaN       NaN      NaN     NaN      NaN     NaN        NaN      111
#
#                 NEIGHBOURHOOD_158 HOOD_140                  NEIGHBOURHOOD_140  \
# 0                 High Park North       88               High Park North (88)
# 1                 High Park North       88               High Park North (88)
# 2                    Malvern East      132                      Malvern (132)
# 3                Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 4                    Malvern East      132                      Malvern (132)
# 5                    Kennedy Park      138                Eglinton East (138)
# 6                Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 7                Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 8                    Kennedy Park      138                Eglinton East (138)
# 9                    Kennedy Park      138                Eglinton East (138)
# 10               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 11               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 12              Trinity-Bellwoods       81             Trinity-Bellwoods (81)
# 13             Princess-Rosethorn       10            Princess-Rosethorn (10)
# 14               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 15              Trinity-Bellwoods       81             Trinity-Bellwoods (81)
# 16               Wexford/Maryvale      119             Wexford/Maryvale (119)
# 17               Woodbine-Lumsden       60              Woodbine-Lumsden (60)
# 18  Kingsview Village-The Westway        6  Kingsview Village-The Westway (6)
# 19               Wexford/Maryvale      119             Wexford/Maryvale (119)
# 20               Wexford/Maryvale      119             Wexford/Maryvale (119)
# 21             Yonge-Bay Corridor       76           Bay Street Corridor (76)
# 22             Yonge-Bay Corridor       76           Bay Street Corridor (76)
# 23             Yonge-Bay Corridor       76           Bay Street Corridor (76)
# 24       Keelesdale-Eglinton West      110     Keelesdale-Eglinton West (110)
# 25       Keelesdale-Eglinton West      110     Keelesdale-Eglinton West (110)
# 26       Keelesdale-Eglinton West      110     Keelesdale-Eglinton West (110)
# 27       Keelesdale-Eglinton West      110     Keelesdale-Eglinton West (110)
# 28       Keelesdale-Eglinton West      110     Keelesdale-Eglinton West (110)
# 29              Rockcliffe-Smythe      111            Rockcliffe-Smythe (111)
#
#    DIVISION  ObjectId  SEASON  Year  Month  Day
# 0       D11         1  Spring  2006      3   11
# 1       D11         2  Spring  2006      3   11
# 2       D42         3  Spring  2006      3   11
# 3       D55         4  Winter  2006      1    1
# 4       D42         5  Spring  2006      3   11
# 5       D41         6  Spring  2006      3   12
# 6       D55         7  Winter  2006      1    1
# 7       D55         8  Winter  2006      1    1
# 8       D41         9  Spring  2006      3   12
# 9       D41        10  Spring  2006      3   12
# 10      D55        11  Winter  2006      1    1
# 11      D55        12  Winter  2006      1    1
# 12      D14        13  Spring  2006      3   12
# 13      D22        14  Summer  2006      6   25
# 14      D55        15  Winter  2006      1    1
# 15      D14        16  Spring  2006      3   12
# 16      D41        17  Summer  2006      6   28
# 17      D55        18  Winter  2006      1    1
# 18      D23        19  Spring  2006      3   15
# 19      D41        20  Summer  2006      6   28
# 20      D41        21  Summer  2006      6   28
# 21      D52        22  Summer  2006      6   28
# 22      D52        23  Summer  2006      6   28
# 23      D52        24  Summer  2006      6   28
# 24      D12        25  Summer  2006      6   28
# 25      D12        26  Summer  2006      6   28
# 26      D12        27  Summer  2006      6   28
# 27      D12        28  Summer  2006      6   28
# 28      D12        29  Summer  2006      6   28
# 29      D12        30  Summer  2006      6   29

# %%
duplicate_accidents = df[df.duplicated(subset=['ACCNUM'], keep=False)]

duplicate_accidents.shape
# Out:
# (14857, 59)

# %%
df = df.sort_values(by='ACCNUM', ascending=False)

# %%
df.head(5)
# Out:
#          INDEX_        ACCNUM  YEAR                      DATE  TIME  \
# 10961  80164629  4.008024e+09  2014 2014-06-19 04:00:00+00:00  1600
# 10966  80164630  4.008024e+09  2014 2014-06-19 04:00:00+00:00  1600
# 10411  80153767  4.008010e+09  2014 2014-03-07 05:00:00+00:00   650
# 10425  80153768  4.008010e+09  2014 2014-03-07 05:00:00+00:00   650
# 10321  80153506  4.008010e+09  2014 2014-03-05 05:00:00+00:00  1800
#
#                      STREET1           STREET2 OFFSET      ROAD_CLASS  \
# 10961          STEELES AVE W          SHALE GT    NaN  Major Arterial
# 10966          STEELES AVE W          SHALE GT    NaN  Major Arterial
# 10411  DON VALLEY PARKWAY  S    LAWRENCE AVE E    NaN             NaN
# 10425  DON VALLEY PARKWAY  S    LAWRENCE AVE E    NaN             NaN
# 10321            FINCH AVE E  BRIDLETOWNE CRCL    NaN  Major Arterial
#
#           DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 10961   North York        6  43.783209 -79.487293  Intersection
# 10966   North York        6  43.783209 -79.487293  Intersection
# 10411   North York       16  43.740267 -79.332240     Mid-Block
# 10425   North York       16  43.740267 -79.332240     Mid-Block
# 10321  Scarborough       22  43.795840 -79.319301  Intersection
#
#                      ACCLOC        TRAFFCTL VISIBILITY             LIGHT  \
# 10961       At Intersection  Traffic Signal      Clear          Daylight
# 10966       At Intersection  Traffic Signal      Clear          Daylight
# 10411      Non Intersection      No Control      Clear          Daylight
# 10425      Non Intersection      No Control      Clear          Daylight
# 10321  Intersection Related  Traffic Signal      Clear  Dusk, artificial
#
#       RDSFCOND           ACCLASS           IMPACTYPE  INVTYPE    INVAGE  \
# 10961      Dry  Non-Fatal Injury  Cyclist Collisions   Driver  40 to 44
# 10966      Dry  Non-Fatal Injury  Cyclist Collisions  Cyclist  55 to 59
# 10411      Dry  Non-Fatal Injury            Rear End   Driver  60 to 64
# 10425      Dry  Non-Fatal Injury            Rear End   Driver  25 to 29
# 10321      Dry  Non-Fatal Injury            Rear End   Driver  30 to 34
#
#       INJURY  FATAL_NO INITDIR                    VEHTYPE  \
# 10961   None       NaN    East  Automobile, Station Wagon
# 10966  Major       NaN   North                    Bicycle
# 10411  Major       NaN   South  Automobile, Station Wagon
# 10425  Major       NaN   South  Automobile, Station Wagon
# 10321  Major       NaN    East  Automobile, Station Wagon
#
#                  MANOEUVER                       DRIVACT     DRIVCOND PEDTYPE  \
# 10961        Turning Right  Failed to Yield Right of Way  Inattentive     NaN
# 10966          Going Ahead                           NaN          NaN     NaN
# 10411              Stopped              Driving Properly       Normal     NaN
# 10425  Slowing or Stopping           Following too Close  Inattentive     NaN
# 10321              Stopped              Driving Properly       Normal     NaN
#
#       PEDACT PEDCOND                                         CYCLISTYPE  \
# 10961    NaN     NaN                                                NaN
# 10966    NaN     NaN  Motorist turning right on red at signalized in...
# 10411    NaN     NaN                                                NaN
# 10425    NaN     NaN                                                NaN
# 10321    NaN     NaN                                                NaN
#
#                  CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE  \
# 10961               NaN     NaN        NaN     Yes        Yes        NaN
# 10966  Driving Properly  Normal        NaN     Yes        Yes        NaN
# 10411               NaN     NaN        NaN     NaN        Yes        NaN
# 10425               NaN     NaN        NaN     NaN        Yes        NaN
# 10321               NaN     NaN        NaN     NaN        Yes        NaN
#
#       TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT  \
# 10961   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10966   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10411   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10425   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10321   NaN           NaN       NaN       NaN      NaN     NaN      NaN
#
#       ALCOHOL DISABILITY HOOD_158        NEIGHBOURHOOD_158 HOOD_140  \
# 10961     NaN        NaN       27  York University Heights       27
# 10966     NaN        NaN       27  York University Heights       27
# 10411     NaN        NaN       42        Banbury-Don Mills       42
# 10425     NaN        NaN       42        Banbury-Don Mills       42
# 10321     NaN        NaN      147          L'Amoreaux West      117
#
#                   NEIGHBOURHOOD_140 DIVISION  ObjectId  SEASON  Year  Month  \
# 10961  York University Heights (27)      D31     10962  Summer  2014      6
# 10966  York University Heights (27)      D31     10967  Summer  2014      6
# 10411        Banbury-Don Mills (42)      D33     10412  Spring  2014      3
# 10425        Banbury-Don Mills (42)      D33     10426  Spring  2014      3
# 10321              L'Amoreaux (117)      D42     10322  Spring  2014      3
#
#        Day
# 10961   19
# 10966   19
# 10411    7
# 10425    7
# 10321    5

# %%
df.columns
# Out:
# Index(['INDEX_', 'ACCNUM', 'YEAR', 'DATE', 'TIME', 'STREET1', 'STREET2',
#        'OFFSET', 'ROAD_CLASS', 'DISTRICT', 'WARDNUM', 'LATITUDE', 'LONGITUDE',
#        'LOCCOORD', 'ACCLOC', 'TRAFFCTL', 'VISIBILITY', 'LIGHT', 'RDSFCOND',
#        'ACCLASS', 'IMPACTYPE', 'INVTYPE', 'INVAGE', 'INJURY', 'FATAL_NO',
#        'INITDIR', 'VEHTYPE', 'MANOEUVER', 'DRIVACT', 'DRIVCOND', 'PEDTYPE',
#        'PEDACT', 'PEDCOND', 'CYCLISTYPE', 'CYCACT', 'CYCCOND', 'PEDESTRIAN',
#        'CYCLIST', 'AUTOMOBILE', 'MOTORCYCLE', 'TRUCK', 'TRSN_CITY_VEH',
#        'EMERG_VEH', 'PASSENGER', 'SPEEDING', 'AG_DRIV', 'REDLIGHT', 'ALCOHOL',
#        'DISABILITY', 'HOOD_158', 'NEIGHBOURHOOD_158', 'HOOD_140',
#        'NEIGHBOURHOOD_140', 'DIVISION', 'ObjectId', 'SEASON', 'Year', 'Month',
#        'Day'],
#       dtype='object')

# %%
one_accident = df[df.duplicated(subset=['TIME', 'DIVISION', 'STREET1', 'STREET2', 'NEIGHBOURHOOD_140', 'HOOD_140'], keep=False)]

# Group by the condition and assign a unique index ID
one_accident['ACC_NUM2'] = one_accident.groupby(['TIME', 'DIVISION', 'STREET1', 'STREET2', 'NEIGHBOURHOOD_140', 'HOOD_140']).ngroup()

# Merge the unique index IDs back to the original DataFrame
df = pd.merge(df, one_accident[['ACC_NUM2']], left_index=True, right_index=True, how='left')

# Fill NaN values in the ACC_NUM column with -1
df['ACC_NUM2'] = df['ACC_NUM2'].fillna(-1)

# Display the DataFrame with the assigned unique index IDs
# Out:
# <ipython-input-317-e5c25b66f725>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(5)
# Out:
#          INDEX_        ACCNUM  YEAR                      DATE  TIME  \
# 10961  80164629  4.008024e+09  2014 2014-06-19 04:00:00+00:00  1600
# 10966  80164630  4.008024e+09  2014 2014-06-19 04:00:00+00:00  1600
# 10411  80153767  4.008010e+09  2014 2014-03-07 05:00:00+00:00   650
# 10425  80153768  4.008010e+09  2014 2014-03-07 05:00:00+00:00   650
# 10321  80153506  4.008010e+09  2014 2014-03-05 05:00:00+00:00  1800
#
#                      STREET1           STREET2 OFFSET      ROAD_CLASS  \
# 10961          STEELES AVE W          SHALE GT    NaN  Major Arterial
# 10966          STEELES AVE W          SHALE GT    NaN  Major Arterial
# 10411  DON VALLEY PARKWAY  S    LAWRENCE AVE E    NaN             NaN
# 10425  DON VALLEY PARKWAY  S    LAWRENCE AVE E    NaN             NaN
# 10321            FINCH AVE E  BRIDLETOWNE CRCL    NaN  Major Arterial
#
#           DISTRICT  WARDNUM   LATITUDE  LONGITUDE      LOCCOORD  \
# 10961   North York        6  43.783209 -79.487293  Intersection
# 10966   North York        6  43.783209 -79.487293  Intersection
# 10411   North York       16  43.740267 -79.332240     Mid-Block
# 10425   North York       16  43.740267 -79.332240     Mid-Block
# 10321  Scarborough       22  43.795840 -79.319301  Intersection
#
#                      ACCLOC        TRAFFCTL VISIBILITY             LIGHT  \
# 10961       At Intersection  Traffic Signal      Clear          Daylight
# 10966       At Intersection  Traffic Signal      Clear          Daylight
# 10411      Non Intersection      No Control      Clear          Daylight
# 10425      Non Intersection      No Control      Clear          Daylight
# 10321  Intersection Related  Traffic Signal      Clear  Dusk, artificial
#
#       RDSFCOND           ACCLASS           IMPACTYPE  INVTYPE    INVAGE  \
# 10961      Dry  Non-Fatal Injury  Cyclist Collisions   Driver  40 to 44
# 10966      Dry  Non-Fatal Injury  Cyclist Collisions  Cyclist  55 to 59
# 10411      Dry  Non-Fatal Injury            Rear End   Driver  60 to 64
# 10425      Dry  Non-Fatal Injury            Rear End   Driver  25 to 29
# 10321      Dry  Non-Fatal Injury            Rear End   Driver  30 to 34
#
#       INJURY  FATAL_NO INITDIR                    VEHTYPE  \
# 10961   None       NaN    East  Automobile, Station Wagon
# 10966  Major       NaN   North                    Bicycle
# 10411  Major       NaN   South  Automobile, Station Wagon
# 10425  Major       NaN   South  Automobile, Station Wagon
# 10321  Major       NaN    East  Automobile, Station Wagon
#
#                  MANOEUVER                       DRIVACT     DRIVCOND PEDTYPE  \
# 10961        Turning Right  Failed to Yield Right of Way  Inattentive     NaN
# 10966          Going Ahead                           NaN          NaN     NaN
# 10411              Stopped              Driving Properly       Normal     NaN
# 10425  Slowing or Stopping           Following too Close  Inattentive     NaN
# 10321              Stopped              Driving Properly       Normal     NaN
#
#       PEDACT PEDCOND                                         CYCLISTYPE  \
# 10961    NaN     NaN                                                NaN
# 10966    NaN     NaN  Motorist turning right on red at signalized in...
# 10411    NaN     NaN                                                NaN
# 10425    NaN     NaN                                                NaN
# 10321    NaN     NaN                                                NaN
#
#                  CYCACT CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE  \
# 10961               NaN     NaN        NaN     Yes        Yes        NaN
# 10966  Driving Properly  Normal        NaN     Yes        Yes        NaN
# 10411               NaN     NaN        NaN     NaN        Yes        NaN
# 10425               NaN     NaN        NaN     NaN        Yes        NaN
# 10321               NaN     NaN        NaN     NaN        Yes        NaN
#
#       TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV REDLIGHT  \
# 10961   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10966   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10411   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10425   NaN           NaN       NaN       NaN      NaN     Yes      NaN
# 10321   NaN           NaN       NaN       NaN      NaN     NaN      NaN
#
#       ALCOHOL DISABILITY HOOD_158        NEIGHBOURHOOD_158 HOOD_140  \
# 10961     NaN        NaN       27  York University Heights       27
# 10966     NaN        NaN       27  York University Heights       27
# 10411     NaN        NaN       42        Banbury-Don Mills       42
# 10425     NaN        NaN       42        Banbury-Don Mills       42
# 10321     NaN        NaN      147          L'Amoreaux West      117
#
#                   NEIGHBOURHOOD_140 DIVISION  ObjectId  SEASON  Year  Month  \
# 10961  York University Heights (27)      D31     10962  Summer  2014      6
# 10966  York University Heights (27)      D31     10967  Summer  2014      6
# 10411        Banbury-Don Mills (42)      D33     10412  Spring  2014      3
# 10425        Banbury-Don Mills (42)      D33     10426  Spring  2014      3
# 10321              L'Amoreaux (117)      D42     10322  Spring  2014      3
#
#        Day  ACC_NUM2
# 10961   19    2613.0
# 10966   19    2613.0
# 10411    7     691.0
# 10425    7     691.0
# 10321    5    3170.0

# %%
df = df.drop(['ACC_NUM_x',	'ACC_NUM_y',	'ACC_NUM2_x',	'ACC_NUM2_y'],axis=1)

# %%
one_accident = df[df.duplicated(subset=['TIME', 'DIVISION', 'STREET1', 'STREET2', 'NEIGHBOURHOOD_140', 'HOOD_140'], keep=False)]

# Group by the condition and assign a unique index ID
one_accident['ACC_NUM'] = one_accident.groupby(['TIME', 'DIVISION', 'STREET1', 'STREET2', 'NEIGHBOURHOOD_140', 'HOOD_140']).ngroup()

# Merge the unique index IDs back to the original DataFrame
df = pd.merge(df, one_accident[['ACC_NUM']], left_index=True, right_index=True, how='left')

# Fill NaN values in the ACC_NUM column with -1
df['ACC_NUM'] = df['ACC_NUM'].fillna(-1)

# Display the DataFrame with the assigned unique index IDs
# Out:
# <ipython-input-325-74217522c0b5>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df = df.sort_values(by='ACC_NUM', ascending=True)

# %%
df.head(30)
# Out:
#          INDEX_        ACCNUM  YEAR                      DATE  TIME  \
# 7796    6804925  1.248931e+06  2011 2011-08-13 04:00:00+00:00  1800
# 6045    6614964  1.228029e+06  2011 2011-03-25 04:00:00+00:00   720
# 6044    6614963  1.228029e+06  2011 2011-03-25 04:00:00+00:00   720
# 10565  80167945  4.002525e+09  2014 2014-07-18 04:00:00+00:00  2340
# 10572  80167946  4.002525e+09  2014 2014-07-18 04:00:00+00:00  2340
# 14730  80941914           NaN  2018 2018-02-23 05:00:00+00:00   118
# 10474  80213442  4.002493e+09  2014 2014-07-14 04:00:00+00:00   450
# 12177  80504002           NaN  2016 2016-05-03 04:00:00+00:00   948
# 14723  80941913           NaN  2018 2018-02-23 05:00:00+00:00   118
# 10414  80213101  4.002469e+09  2014 2014-07-10 04:00:00+00:00  1235
# 14740  80900781           NaN  2018 2018-04-12 04:00:00+00:00  1425
# 10397  80213080  4.002467e+09  2014 2014-07-10 04:00:00+00:00   759
# 14715  80941912           NaN  2018 2018-02-23 05:00:00+00:00   118
# 12169  80490904           NaN  2015 2015-10-21 04:00:00+00:00  1327
# 12165  80253637           NaN  2015 2015-10-20 04:00:00+00:00   923
# 10318  80212823  4.002444e+09  2014 2014-07-06 04:00:00+00:00  1819
# 10312  80630546  4.002412e+09  2014 2014-07-02 04:00:00+00:00   650
# 12164  80253636           NaN  2015 2015-10-20 04:00:00+00:00   923
# 6277    6617160  1.229003e+06  2011 2011-04-20 04:00:00+00:00  1910
# 14747  80900782           NaN  2018 2018-04-12 04:00:00+00:00  1425
# 12601  80565332           NaN  2016 2016-09-16 04:00:00+00:00  1242
# 10404  80213081  4.002467e+09  2014 2014-07-10 04:00:00+00:00   759
# 14767  80942989           NaN  2018 2018-05-22 04:00:00+00:00  1325
# 12530  80545824           NaN  2016 2016-07-12 04:00:00+00:00  1710
# 10606  80168509  4.002555e+09  2014 2014-07-23 04:00:00+00:00  1135
# 1817    4137575  9.548520e+05  2007 2007-02-21 05:00:00+00:00  1405
# 12701  80632430           NaN  2016 2016-02-29 05:00:00+00:00  1939
# 12044  80632107           NaN  2016 2016-08-13 04:00:00+00:00  2223
# 7671    6705452  1.266936e+06  2011 2011-09-25 04:00:00+00:00   130
# 2652    4235738  9.979050e+05  2007 2007-10-06 04:00:00+00:00  1630
#
#                      STREET1                   STREET2          OFFSET  \
# 7796         28 REGATTA CRES                       NaN             NaN
# 6045             315 MAIN ST                       NaN             NaN
# 6044             315 MAIN ST                       NaN             NaN
# 10565           3900 JANE ST                       NaN             NaN
# 10572           3900 JANE ST                       NaN             NaN
# 14730       931 PROGRESS AVE                       NaN     5 m West of
# 10474               DIXON RD              CELESTINE DR             NaN
# 12177       3 SPRUCE HILL RD                       NaN             NaN
# 14723       931 PROGRESS AVE                       NaN     5 m West of
# 10414          HIGHWAY 27  N             ROYALCREST RD             NaN
# 14740        625 FINCH AVE W                       NaN             NaN
# 10397         1140 LESLIE ST                       NaN             NaN
# 14715       931 PROGRESS AVE                       NaN     5 m West of
# 12169               KEELE ST                TILBURY DR             NaN
# 12165         1245 DUPONT ST                       NaN    25 m West of
# 10318  DON VALLEY PARKWAY  S  BAYVIEW BLOOR DVP S RAMP  100 m South of
# 10312            COXWELL AVE              GERRARD ST E    1 m North of
# 12164         1245 DUPONT ST                       NaN    25 m West of
# 6277         4335 BLOOR ST W                       NaN             NaN
# 14747        625 FINCH AVE W                       NaN             NaN
# 12601      110 ST REGIS CRES                       NaN             NaN
# 10404         1140 LESLIE ST                       NaN             NaN
# 14767         4800 LESLIE ST                       NaN    60 m West of
# 12530          BIRMINGHAM ST             ELSINORE PATH             NaN
# 10606       50 CUMBERLAND ST                       NaN             NaN
# 1817         16 HISCOCK BLVD                       NaN             NaN
# 12701  137 QUEEN S PLATE  DR                       NaN    1 m North of
# 12044      LAKE SHORE BLVD W           LONG BRANCH AVE    40 m West of
# 7671         1279 BLOOR St W                       NaN             NaN
# 2652          695 WILSON Ave                       NaN             NaN
#
#            ROAD_CLASS               DISTRICT  WARDNUM   LATITUDE  LONGITUDE  \
# 7796            Local             North York       18  43.789345 -79.443890
# 6045   Minor Arterial  Toronto and East York       19  43.689044 -79.302287
# 6044   Minor Arterial  Toronto and East York       19  43.689044 -79.302287
# 10565  Major Arterial         Etobicoke York        7  43.756663 -79.517566
# 10572  Major Arterial         Etobicoke York        7  43.756663 -79.517566
# 14730  Minor Arterial            Scarborough       24  43.783801 -79.231838
# 10474  Major Arterial         Etobicoke York       12  43.693392 -79.562503
# 12177           Local  Toronto and East York       19  43.672747 -79.288913
# 14723  Minor Arterial            Scarborough       24  43.783801 -79.231838
# 10414  Major Arterial         Etobicoke York        1  43.749705 -79.610454
# 14740  Major Arterial             North York        6  43.771510 -79.454334
# 10397  Major Arterial             North York     1516  43.726092 -79.349811
# 14715  Minor Arterial            Scarborough       24  43.783801 -79.231838
# 12169  Major Arterial             North York        6  43.730334 -79.482967
# 12165  Major Arterial  Toronto and East York        9  43.668135 -79.441852
# 10318             NaN  Toronto and East York       14  43.681025 -79.362567
# 10312  Minor Arterial  Toronto and East York     1419  43.675261 -79.320270
# 12164  Major Arterial  Toronto and East York        9  43.668135 -79.441852
# 6277   Major Arterial         Etobicoke York        2  43.631645 -79.575990
# 14747  Major Arterial             North York        6  43.771510 -79.454334
# 12601           Local             North York        6  43.754729 -79.482974
# 10404  Major Arterial             North York     1516  43.726092 -79.349811
# 14767  Major Arterial             North York       17  43.779692 -79.365611
# 12530       Collector         Etobicoke York        3  43.602278 -79.510753
# 10606       Collector  Toronto and East York       11  43.670752 -79.388912
# 1817        Collector            Scarborough       24  43.762345 -79.222090
# 12701       Collector         Etobicoke York        1  43.717261 -79.592593
# 12044  Major Arterial         Etobicoke York        3  43.594142 -79.534580
# 7671   Major Arterial  Toronto and East York        9  43.658445 -79.442190
# 2652   Major Arterial             North York        6  43.732445 -79.456890
#
#            LOCCOORD                 ACCLOC        TRAFFCTL VISIBILITY  \
# 7796   Intersection                    NaN      No Control      Clear
# 6045      Mid-Block                    NaN      No Control      Clear
# 6044      Mid-Block                    NaN      No Control      Clear
# 10565     Mid-Block  At/Near Private Drive      No Control      Clear
# 10572     Mid-Block  At/Near Private Drive      No Control      Clear
# 14730  Intersection   Intersection Related  Traffic Signal      Clear
# 10474  Intersection        At Intersection  Traffic Signal      Clear
# 12177     Mid-Block       Non Intersection      No Control      Clear
# 14723  Intersection   Intersection Related  Traffic Signal      Clear
# 10414  Intersection        At Intersection  Traffic Signal      Clear
# 14740  Intersection        At Intersection  Traffic Signal      Clear
# 10397     Mid-Block       Non Intersection      No Control      Clear
# 14715  Intersection   Intersection Related  Traffic Signal      Clear
# 12169  Intersection   Intersection Related  Traffic Signal      Clear
# 12165     Mid-Block       Non Intersection      No Control      Clear
# 10318     Mid-Block       Non Intersection      No Control      Clear
# 10312  Intersection        At Intersection  Traffic Signal      Clear
# 12164     Mid-Block       Non Intersection      No Control      Clear
# 6277      Mid-Block                    NaN      No Control      Clear
# 14747  Intersection        At Intersection  Traffic Signal      Clear
# 12601     Mid-Block  At/Near Private Drive      No Control      Clear
# 10404     Mid-Block       Non Intersection      No Control      Clear
# 14767     Mid-Block       Non Intersection      No Control      Clear
# 12530  Intersection        At Intersection      No Control      Clear
# 10606     Mid-Block       Non Intersection      No Control      Clear
# 1817      Mid-Block                    NaN      No Control      Clear
# 12701     Mid-Block       Non Intersection      No Control      Clear
# 12044     Mid-Block       Non Intersection      No Control      Clear
# 7671      Mid-Block                    NaN      No Control      Clear
# 2652      Mid-Block                    NaN      No Control       Rain
#
#                       LIGHT RDSFCOND           ACCLASS              IMPACTYPE  \
# 7796               Daylight      Dry             Fatal  Pedestrian Collisions
# 6045               Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 6044               Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 10565              Daylight      Dry  Non-Fatal Injury     Cyclist Collisions
# 10572              Daylight      Dry  Non-Fatal Injury     Cyclist Collisions
# 14730      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 10474      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 12177              Daylight      Dry             Fatal  Pedestrian Collisions
# 14723      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 10414              Daylight      Dry  Non-Fatal Injury              SMV Other
# 14740              Daylight      Wet  Non-Fatal Injury  Pedestrian Collisions
# 10397              Daylight      Dry  Non-Fatal Injury               Rear End
# 14715      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 12169              Daylight      Dry  Non-Fatal Injury              SMV Other
# 12165              Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 10318              Daylight      Dry  Non-Fatal Injury              SMV Other
# 10312              Daylight      Dry  Non-Fatal Injury              SMV Other
# 12164              Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 6277               Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 14747              Daylight      Wet  Non-Fatal Injury  Pedestrian Collisions
# 12601              Daylight      Dry             Fatal  Pedestrian Collisions
# 10404              Daylight      Dry  Non-Fatal Injury               Rear End
# 14767  Daylight, artificial      Dry  Non-Fatal Injury  Pedestrian Collisions
# 12530              Daylight      Dry             Fatal              SMV Other
# 10606              Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 1817               Daylight      Dry  Non-Fatal Injury            Approaching
# 12701                  Dusk      Dry  Non-Fatal Injury  Pedestrian Collisions
# 12044      Dark, artificial      Wet  Non-Fatal Injury              SMV Other
# 7671                   Dark      Dry  Non-Fatal Injury  Pedestrian Collisions
# 2652               Daylight      Wet  Non-Fatal Injury               Rear End
#
#                  INVTYPE    INVAGE INJURY  FATAL_NO  INITDIR  \
# 7796          Pedestrian  75 to 79  Fatal      19.0    South
# 6045          Pedestrian  45 to 49  Major       NaN     East
# 6044              Driver   unknown   None       NaN    North
# 10565             Driver  35 to 39   None       NaN     East
# 10572            Cyclist  30 to 34  Major       NaN  Unknown
# 14730             Driver  25 to 29  Minor       NaN    North
# 10474             Driver  20 to 24  Major       NaN     East
# 12177             Driver  65 to 69   None       NaN     East
# 14723          Passenger  20 to 24  Major       NaN      NaN
# 10414             Driver  60 to 64  Major       NaN    South
# 14740         Pedestrian  10 to 14  Minor       NaN    North
# 10397             Driver  35 to 39  Minor       NaN    South
# 14715          Passenger  20 to 24  Major       NaN      NaN
# 12169             Driver  75 to 79  Major       NaN    South
# 12165         Pedestrian  40 to 44  Major       NaN  Unknown
# 10318  Motorcycle Driver  35 to 39  Major       NaN    South
# 10312             Driver  65 to 69  Major       NaN    North
# 12164          Passenger  55 to 59   None       NaN      NaN
# 6277          Pedestrian  55 to 59  Major       NaN    South
# 14747             Driver  35 to 39   None       NaN    North
# 12601         Pedestrian  80 to 84  Fatal      57.0  Unknown
# 10404             Driver  25 to 29  Major       NaN    South
# 14767             Driver  70 to 74   None       NaN    North
# 12530             Driver  55 to 59  Fatal      46.0     West
# 10606         Pedestrian  70 to 74  Major       NaN    South
# 1817       Vehicle Owner   unknown   None       NaN      NaN
# 12701         Pedestrian  50 to 54  Major       NaN     West
# 12044  Motorcycle Driver  25 to 29  Major       NaN     East
# 7671          Pedestrian  50 to 54  Major       NaN    South
# 2652              Driver  45 to 49  Major       NaN     East
#
#                          VEHTYPE                           MANOEUVER  \
# 7796                       Other                                 NaN
# 6045                       Other                                 NaN
# 6044   Automobile, Station Wagon  Pulling Away from Shoulder or Curb
# 10565  Automobile, Station Wagon                         Going Ahead
# 10572                    Bicycle                             Unknown
# 14730  Automobile, Station Wagon                         Going Ahead
# 10474  Automobile, Station Wagon                         Going Ahead
# 12177  Automobile, Station Wagon                       Turning Right
# 14723                        NaN                                 NaN
# 10414  Automobile, Station Wagon                         Going Ahead
# 14740                        NaN                                 NaN
# 10397  Automobile, Station Wagon                         Going Ahead
# 14715                        NaN                                 NaN
# 12169  Automobile, Station Wagon                         Going Ahead
# 12165                        NaN                                 NaN
# 10318                 Motorcycle                         Going Ahead
# 10312  Automobile, Station Wagon                       Turning Right
# 12164                        NaN                                 NaN
# 6277                       Other                                 NaN
# 14747  Automobile, Station Wagon                        Turning Left
# 12601                        NaN                                 NaN
# 10404  Automobile, Station Wagon                 Slowing or Stopping
# 14767  Automobile, Station Wagon                         Going Ahead
# 12530  Automobile, Station Wagon                         Going Ahead
# 10606                        NaN                                 NaN
# 1817                       Other                                 NaN
# 12701                        NaN                                 NaN
# 12044                 Motorcycle                         Going Ahead
# 7671                       Other                                 NaN
# 2652   Automobile, Station Wagon                             Stopped
#
#                             DRIVACT                            DRIVCOND  \
# 7796                            NaN                                 NaN
# 6045                            NaN                                 NaN
# 6044                            NaN                                 NaN
# 10565                         Other                             Unknown
# 10572                           NaN                                 NaN
# 14730                         Other  Ability Impaired, Alcohol Over .08
# 10474                  Lost control                             Fatigue
# 12177                  Lost control                             Unknown
# 14723                           NaN                                 NaN
# 10414                  Lost control                             Unknown
# 14740                           NaN                                 NaN
# 10397  Failed to Yield Right of Way                              Normal
# 14715                           NaN                                 NaN
# 12169                  Lost control                             Unknown
# 12165                           NaN                                 NaN
# 10318                  Lost control                              Normal
# 10312                  Lost control                              Normal
# 12164                           NaN                                 NaN
# 6277                            NaN                                 NaN
# 14747              Driving Properly                              Normal
# 12601                           NaN                                 NaN
# 10404              Driving Properly                              Normal
# 14767              Driving Properly                              Normal
# 12530                  Lost control      Medical or Physical Disability
# 10606                           NaN                                 NaN
# 1817                            NaN                                 NaN
# 12701                           NaN                                 NaN
# 12044                  Lost control                         Inattentive
# 7671                            NaN                                 NaN
# 2652            Following too Close                         Inattentive
#
#                                                  PEDTYPE  \
# 7796                  Pedestrian hit at private driveway
# 6045                         Pedestrian hit at mid-block
# 6044                                                 NaN
# 10565                                                NaN
# 10572                                                NaN
# 14730                                                NaN
# 10474                                                NaN
# 12177                                                NaN
# 14723                                                NaN
# 10414                                                NaN
# 14740  Vehicle is going straight thru inter.while ped...
# 10397                                                NaN
# 14715                                                NaN
# 12169                                                NaN
# 12165                        Pedestrian hit at mid-block
# 10318                                                NaN
# 10312                                                NaN
# 12164                                                NaN
# 6277   Vehicle turns left while ped crosses without R...
# 14747                                                NaN
# 12601           Vehicle is reversing and hits pedestrian
# 10404                                                NaN
# 14767                                                NaN
# 12530                                                NaN
# 10606           Vehicle is reversing and hits pedestrian
# 1817                                                 NaN
# 12701                        Pedestrian hit at mid-block
# 12044                                                NaN
# 7671                         Pedestrian hit at mid-block
# 2652                                                 NaN
#
#                              PEDACT      PEDCOND  \
# 7796        On Sidewalk or Shoulder      Unknown
# 6045   Crossing, no Traffic Control       Normal
# 6044                            NaN          NaN
# 10565                           NaN          NaN
# 10572                           NaN          NaN
# 14730                           NaN          NaN
# 10474                           NaN          NaN
# 12177                           NaN          NaN
# 14723                           NaN          NaN
# 10414                           NaN          NaN
# 14740    Crossing with right of way       Normal
# 10397                           NaN          NaN
# 14715                           NaN          NaN
# 12169                           NaN          NaN
# 12165                         Other       Normal
# 10318                           NaN          NaN
# 10312                           NaN          NaN
# 12164                           NaN          NaN
# 6277   Crossing, no Traffic Control  Inattentive
# 14747                           NaN          NaN
# 12601       On Sidewalk or Shoulder      Unknown
# 10404                           NaN          NaN
# 14767                           NaN          NaN
# 12530                           NaN          NaN
# 10606                         Other      Unknown
# 1817                            NaN          NaN
# 12701  Crossing, no Traffic Control  Inattentive
# 12044                           NaN          NaN
# 7671   Crossing, no Traffic Control       Normal
# 2652                            NaN          NaN
#
#                                               CYCLISTYPE CYCACT  CYCCOND  \
# 7796                                                 NaN    NaN      NaN
# 6045                                                 NaN    NaN      NaN
# 6044                                                 NaN    NaN      NaN
# 10565                                                NaN    NaN      NaN
# 10572  Motorist without ROW drives into path of cycli...  Other  Unknown
# 14730                                                NaN    NaN      NaN
# 10474                                                NaN    NaN      NaN
# 12177                                                NaN    NaN      NaN
# 14723                                                NaN    NaN      NaN
# 10414                                                NaN    NaN      NaN
# 14740                                                NaN    NaN      NaN
# 10397                                                NaN    NaN      NaN
# 14715                                                NaN    NaN      NaN
# 12169                                                NaN    NaN      NaN
# 12165                                                NaN    NaN      NaN
# 10318                                                NaN    NaN      NaN
# 10312                                                NaN    NaN      NaN
# 12164                                                NaN    NaN      NaN
# 6277                                                 NaN    NaN      NaN
# 14747                                                NaN    NaN      NaN
# 12601                                                NaN    NaN      NaN
# 10404                                                NaN    NaN      NaN
# 14767                                                NaN    NaN      NaN
# 12530                                                NaN    NaN      NaN
# 10606                                                NaN    NaN      NaN
# 1817                                                 NaN    NaN      NaN
# 12701                                                NaN    NaN      NaN
# 12044                                                NaN    NaN      NaN
# 7671                                                 NaN    NaN      NaN
# 2652                                                 NaN    NaN      NaN
#
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 7796         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 6045         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 6044         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10565        NaN     Yes        Yes        NaN   NaN           NaN       NaN
# 10572        NaN     Yes        Yes        NaN   NaN           NaN       NaN
# 14730        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 10474        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12177        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 14723        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 10414        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14740        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10397        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14715        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12169        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12165        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10318        NaN     NaN        NaN        Yes   NaN           NaN       NaN
# 10312        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12164        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 6277         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 14747        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 12601        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10404        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14767        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 12530        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 10606        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 1817         NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12701        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 12044        NaN     NaN        NaN        Yes   NaN           NaN       NaN
# 7671         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 2652         NaN     NaN        Yes        NaN   NaN           NaN       NaN
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 7796        NaN      NaN     NaN      NaN     NaN        NaN       36
# 6045        NaN      NaN     NaN      NaN     NaN        NaN       62
# 6044        NaN      NaN     NaN      NaN     NaN        NaN       62
# 10565       NaN      NaN     NaN      NaN     NaN        NaN       25
# 10572       NaN      NaN     NaN      NaN     NaN        NaN       25
# 14730       Yes      NaN     NaN      NaN     Yes        NaN      142
# 10474       NaN      NaN     NaN      NaN     NaN        NaN        7
# 12177       NaN      NaN     NaN      NaN     NaN        NaN       63
# 14723       Yes      NaN     NaN      NaN     Yes        NaN      142
# 10414       NaN      NaN     NaN      NaN     NaN        NaN        1
# 14740       NaN      NaN     Yes      Yes     NaN        NaN       35
# 10397       NaN      NaN     Yes      NaN     NaN        NaN       42
# 14715       Yes      NaN     NaN      NaN     Yes        NaN      142
# 12169       NaN      NaN     Yes      NaN     NaN        NaN      155
# 12165       Yes      NaN     NaN      NaN     NaN        NaN      171
# 10318       NaN      NaN     Yes      NaN     NaN        NaN       57
# 10312       NaN      Yes     Yes      NaN     NaN        NaN       64
# 12164       Yes      NaN     NaN      NaN     NaN        NaN      171
# 6277        NaN      NaN     NaN      NaN     NaN        NaN       12
# 14747       NaN      NaN     Yes      Yes     NaN        NaN       35
# 12601       NaN      NaN     Yes      NaN     NaN        NaN       27
# 10404       NaN      NaN     Yes      NaN     NaN        NaN       42
# 14767       Yes      NaN     NaN      NaN     NaN        NaN       47
# 12530       NaN      NaN     NaN      NaN     NaN        Yes       18
# 10606       NaN      NaN     NaN      NaN     NaN        NaN       95
# 1817        NaN      Yes     Yes      NaN     Yes        NaN      141
# 12701       NaN      NaN     NaN      NaN     NaN        NaN        1
# 12044       NaN      NaN     NaN      NaN     NaN        NaN       19
# 7671        NaN      NaN     NaN      NaN     NaN        NaN       83
# 2652        NaN      NaN     Yes      NaN     NaN        NaN       33
#
#                       NEIGHBOURHOOD_158 HOOD_140  \
# 7796                   Newtonbrook West       36
# 6045                  East End-Danforth       62
# 6044                  East End-Danforth       62
# 10565            Glenfield-Jane Heights       25
# 10572            Glenfield-Jane Heights       25
# 14730                      Woburn North      137
# 10474  Willowridge-Martingrove-Richview        7
# 12177                       The Beaches       63
# 14723                      Woburn North      137
# 10414            West Humber-Clairville        1
# 14740               Westminster-Branson       35
# 10397                 Banbury-Don Mills       42
# 14715                      Woburn North      137
# 12169                         Downsview       26
# 12165          Junction-Wallace Emerson       93
# 10318                   Broadview North       57
# 10312                 Woodbine Corridor       64
# 12164          Junction-Wallace Emerson       93
# 6277                      Markland Wood       12
# 14747               Westminster-Branson       35
# 12601           York University Heights       27
# 10404                 Banbury-Don Mills       42
# 14767                Don Valley Village       47
# 12530                       New Toronto       18
# 10606                             Annex       95
# 1817          Golfdale-Cedarbrae-Woburn      137
# 12701            West Humber-Clairville        1
# 12044                       Long Branch       19
# 7671                     Dufferin Grove       83
# 2652                       Clanton Park       33
#
#                               NEIGHBOURHOOD_140 DIVISION  ObjectId  SEASON  \
# 7796                      Newtonbrook West (36)      D32      7797  Summer
# 6045                     East End-Danforth (62)      D55      6046  Spring
# 6044                     East End-Danforth (62)      D55      6045  Spring
# 10565               Glenfield-Jane Heights (25)      D31     10566  Summer
# 10572               Glenfield-Jane Heights (25)      D31     10573  Summer
# 14730                              Woburn (137)      D43     14731  Winter
# 10474      Willowridge-Martingrove-Richview (7)      D23     10475  Summer
# 12177                          The Beaches (63)      D55     12178  Spring
# 14723                              Woburn (137)      D43     14724  Winter
# 10414                West Humber-Clairville (1)      D23     10415  Summer
# 14740                  Westminster-Branson (35)      D32     14741  Spring
# 10397                    Banbury-Don Mills (42)      D33     10398  Summer
# 14715                              Woburn (137)      D43     14716  Winter
# 12169                 Downsview-Roding-CFB (26)      D31     12170  Autumn
# 12165  Dovercourt-Wallace Emerson-Junction (93)      D11     12166  Autumn
# 10318                      Broadview North (57)      D55     10319  Summer
# 10312                    Woodbine Corridor (64)      D55     10313  Summer
# 12164  Dovercourt-Wallace Emerson-Junction (93)      D11     12165  Autumn
# 6277                         Markland Wood (12)      D22      6278  Spring
# 14747                  Westminster-Branson (35)      D32     14748  Spring
# 12601              York University Heights (27)      D31     12602  Autumn
# 10404                    Banbury-Don Mills (42)      D33     10405  Summer
# 14767                   Don Valley Village (47)      D33     14768  Spring
# 12530                          New Toronto (18)      D22     12531  Summer
# 10606                                Annex (95)      D53     10607  Summer
# 1817                               Woburn (137)      D43      1818  Winter
# 12701                West Humber-Clairville (1)      D23     12702  Winter
# 12044                          Long Branch (19)      D22     12045  Summer
# 7671                        Dufferin Grove (83)      D11      7672  Autumn
# 2652                          Clanton Park (33)      D32      2653  Autumn
#
#        Year  Month  Day  ACC_NUM2  ACC_NUM
# 7796   2011      8   13      -1.0     -1.0
# 6045   2011      3   25      -1.0     -1.0
# 6044   2011      3   25      -1.0     -1.0
# 10565  2014      7   18      -1.0     -1.0
# 10572  2014      7   18      -1.0     -1.0
# 14730  2018      2   23      -1.0     -1.0
# 10474  2014      7   14      -1.0     -1.0
# 12177  2016      5    3      -1.0     -1.0
# 14723  2018      2   23      -1.0     -1.0
# 10414  2014      7   10      -1.0     -1.0
# 14740  2018      4   12      -1.0     -1.0
# 10397  2014      7   10      -1.0     -1.0
# 14715  2018      2   23      -1.0     -1.0
# 12169  2015     10   21      -1.0     -1.0
# 12165  2015     10   20      -1.0     -1.0
# 10318  2014      7    6      -1.0     -1.0
# 10312  2014      7    2      -1.0     -1.0
# 12164  2015     10   20      -1.0     -1.0
# 6277   2011      4   20      -1.0     -1.0
# 14747  2018      4   12      -1.0     -1.0
# 12601  2016      9   16      -1.0     -1.0
# 10404  2014      7   10      -1.0     -1.0
# 14767  2018      5   22      -1.0     -1.0
# 12530  2016      7   12      -1.0     -1.0
# 10606  2014      7   23      -1.0     -1.0
# 1817   2007      2   21      -1.0     -1.0
# 12701  2016      2   29      -1.0     -1.0
# 12044  2016      8   13      -1.0     -1.0
# 7671   2011      9   25      -1.0     -1.0
# 2652   2007     10    6      -1.0     -1.0

# %%
df[df.duplicated(subset=['DATE','TIME','ACC_NUM'], keep=False)]

# %%
pd.set_option("display.max_columns", None)

# %%
df['ACC_NUM'].replace(-1, np.nan, inplace=True)

# %%
df.drop(["ACC_NUM2"], axis=1)

# %%
df.head(30)
# Out:
#          INDEX_        ACCNUM  YEAR                      DATE  TIME  \
# 7796    6804925  1.248931e+06  2011 2011-08-13 04:00:00+00:00  1800
# 6045    6614964  1.228029e+06  2011 2011-03-25 04:00:00+00:00   720
# 6044    6614963  1.228029e+06  2011 2011-03-25 04:00:00+00:00   720
# 10565  80167945  4.002525e+09  2014 2014-07-18 04:00:00+00:00  2340
# 10572  80167946  4.002525e+09  2014 2014-07-18 04:00:00+00:00  2340
# 14730  80941914           NaN  2018 2018-02-23 05:00:00+00:00   118
# 10474  80213442  4.002493e+09  2014 2014-07-14 04:00:00+00:00   450
# 12177  80504002           NaN  2016 2016-05-03 04:00:00+00:00   948
# 14723  80941913           NaN  2018 2018-02-23 05:00:00+00:00   118
# 10414  80213101  4.002469e+09  2014 2014-07-10 04:00:00+00:00  1235
# 14740  80900781           NaN  2018 2018-04-12 04:00:00+00:00  1425
# 10397  80213080  4.002467e+09  2014 2014-07-10 04:00:00+00:00   759
# 14715  80941912           NaN  2018 2018-02-23 05:00:00+00:00   118
# 12169  80490904           NaN  2015 2015-10-21 04:00:00+00:00  1327
# 12165  80253637           NaN  2015 2015-10-20 04:00:00+00:00   923
# 10318  80212823  4.002444e+09  2014 2014-07-06 04:00:00+00:00  1819
# 10312  80630546  4.002412e+09  2014 2014-07-02 04:00:00+00:00   650
# 12164  80253636           NaN  2015 2015-10-20 04:00:00+00:00   923
# 6277    6617160  1.229003e+06  2011 2011-04-20 04:00:00+00:00  1910
# 14747  80900782           NaN  2018 2018-04-12 04:00:00+00:00  1425
# 12601  80565332           NaN  2016 2016-09-16 04:00:00+00:00  1242
# 10404  80213081  4.002467e+09  2014 2014-07-10 04:00:00+00:00   759
# 14767  80942989           NaN  2018 2018-05-22 04:00:00+00:00  1325
# 12530  80545824           NaN  2016 2016-07-12 04:00:00+00:00  1710
# 10606  80168509  4.002555e+09  2014 2014-07-23 04:00:00+00:00  1135
# 1817    4137575  9.548520e+05  2007 2007-02-21 05:00:00+00:00  1405
# 12701  80632430           NaN  2016 2016-02-29 05:00:00+00:00  1939
# 12044  80632107           NaN  2016 2016-08-13 04:00:00+00:00  2223
# 7671    6705452  1.266936e+06  2011 2011-09-25 04:00:00+00:00   130
# 2652    4235738  9.979050e+05  2007 2007-10-06 04:00:00+00:00  1630
#
#                      STREET1                   STREET2          OFFSET  \
# 7796         28 REGATTA CRES                       NaN             NaN
# 6045             315 MAIN ST                       NaN             NaN
# 6044             315 MAIN ST                       NaN             NaN
# 10565           3900 JANE ST                       NaN             NaN
# 10572           3900 JANE ST                       NaN             NaN
# 14730       931 PROGRESS AVE                       NaN     5 m West of
# 10474               DIXON RD              CELESTINE DR             NaN
# 12177       3 SPRUCE HILL RD                       NaN             NaN
# 14723       931 PROGRESS AVE                       NaN     5 m West of
# 10414          HIGHWAY 27  N             ROYALCREST RD             NaN
# 14740        625 FINCH AVE W                       NaN             NaN
# 10397         1140 LESLIE ST                       NaN             NaN
# 14715       931 PROGRESS AVE                       NaN     5 m West of
# 12169               KEELE ST                TILBURY DR             NaN
# 12165         1245 DUPONT ST                       NaN    25 m West of
# 10318  DON VALLEY PARKWAY  S  BAYVIEW BLOOR DVP S RAMP  100 m South of
# 10312            COXWELL AVE              GERRARD ST E    1 m North of
# 12164         1245 DUPONT ST                       NaN    25 m West of
# 6277         4335 BLOOR ST W                       NaN             NaN
# 14747        625 FINCH AVE W                       NaN             NaN
# 12601      110 ST REGIS CRES                       NaN             NaN
# 10404         1140 LESLIE ST                       NaN             NaN
# 14767         4800 LESLIE ST                       NaN    60 m West of
# 12530          BIRMINGHAM ST             ELSINORE PATH             NaN
# 10606       50 CUMBERLAND ST                       NaN             NaN
# 1817         16 HISCOCK BLVD                       NaN             NaN
# 12701  137 QUEEN S PLATE  DR                       NaN    1 m North of
# 12044      LAKE SHORE BLVD W           LONG BRANCH AVE    40 m West of
# 7671         1279 BLOOR St W                       NaN             NaN
# 2652          695 WILSON Ave                       NaN             NaN
#
#            ROAD_CLASS               DISTRICT  WARDNUM   LATITUDE  LONGITUDE  \
# 7796            Local             North York       18  43.789345 -79.443890
# 6045   Minor Arterial  Toronto and East York       19  43.689044 -79.302287
# 6044   Minor Arterial  Toronto and East York       19  43.689044 -79.302287
# 10565  Major Arterial         Etobicoke York        7  43.756663 -79.517566
# 10572  Major Arterial         Etobicoke York        7  43.756663 -79.517566
# 14730  Minor Arterial            Scarborough       24  43.783801 -79.231838
# 10474  Major Arterial         Etobicoke York       12  43.693392 -79.562503
# 12177           Local  Toronto and East York       19  43.672747 -79.288913
# 14723  Minor Arterial            Scarborough       24  43.783801 -79.231838
# 10414  Major Arterial         Etobicoke York        1  43.749705 -79.610454
# 14740  Major Arterial             North York        6  43.771510 -79.454334
# 10397  Major Arterial             North York     1516  43.726092 -79.349811
# 14715  Minor Arterial            Scarborough       24  43.783801 -79.231838
# 12169  Major Arterial             North York        6  43.730334 -79.482967
# 12165  Major Arterial  Toronto and East York        9  43.668135 -79.441852
# 10318             NaN  Toronto and East York       14  43.681025 -79.362567
# 10312  Minor Arterial  Toronto and East York     1419  43.675261 -79.320270
# 12164  Major Arterial  Toronto and East York        9  43.668135 -79.441852
# 6277   Major Arterial         Etobicoke York        2  43.631645 -79.575990
# 14747  Major Arterial             North York        6  43.771510 -79.454334
# 12601           Local             North York        6  43.754729 -79.482974
# 10404  Major Arterial             North York     1516  43.726092 -79.349811
# 14767  Major Arterial             North York       17  43.779692 -79.365611
# 12530       Collector         Etobicoke York        3  43.602278 -79.510753
# 10606       Collector  Toronto and East York       11  43.670752 -79.388912
# 1817        Collector            Scarborough       24  43.762345 -79.222090
# 12701       Collector         Etobicoke York        1  43.717261 -79.592593
# 12044  Major Arterial         Etobicoke York        3  43.594142 -79.534580
# 7671   Major Arterial  Toronto and East York        9  43.658445 -79.442190
# 2652   Major Arterial             North York        6  43.732445 -79.456890
#
#            LOCCOORD                 ACCLOC        TRAFFCTL VISIBILITY  \
# 7796   Intersection                    NaN      No Control      Clear
# 6045      Mid-Block                    NaN      No Control      Clear
# 6044      Mid-Block                    NaN      No Control      Clear
# 10565     Mid-Block  At/Near Private Drive      No Control      Clear
# 10572     Mid-Block  At/Near Private Drive      No Control      Clear
# 14730  Intersection   Intersection Related  Traffic Signal      Clear
# 10474  Intersection        At Intersection  Traffic Signal      Clear
# 12177     Mid-Block       Non Intersection      No Control      Clear
# 14723  Intersection   Intersection Related  Traffic Signal      Clear
# 10414  Intersection        At Intersection  Traffic Signal      Clear
# 14740  Intersection        At Intersection  Traffic Signal      Clear
# 10397     Mid-Block       Non Intersection      No Control      Clear
# 14715  Intersection   Intersection Related  Traffic Signal      Clear
# 12169  Intersection   Intersection Related  Traffic Signal      Clear
# 12165     Mid-Block       Non Intersection      No Control      Clear
# 10318     Mid-Block       Non Intersection      No Control      Clear
# 10312  Intersection        At Intersection  Traffic Signal      Clear
# 12164     Mid-Block       Non Intersection      No Control      Clear
# 6277      Mid-Block                    NaN      No Control      Clear
# 14747  Intersection        At Intersection  Traffic Signal      Clear
# 12601     Mid-Block  At/Near Private Drive      No Control      Clear
# 10404     Mid-Block       Non Intersection      No Control      Clear
# 14767     Mid-Block       Non Intersection      No Control      Clear
# 12530  Intersection        At Intersection      No Control      Clear
# 10606     Mid-Block       Non Intersection      No Control      Clear
# 1817      Mid-Block                    NaN      No Control      Clear
# 12701     Mid-Block       Non Intersection      No Control      Clear
# 12044     Mid-Block       Non Intersection      No Control      Clear
# 7671      Mid-Block                    NaN      No Control      Clear
# 2652      Mid-Block                    NaN      No Control       Rain
#
#                       LIGHT RDSFCOND           ACCLASS              IMPACTYPE  \
# 7796               Daylight      Dry             Fatal  Pedestrian Collisions
# 6045               Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 6044               Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 10565              Daylight      Dry  Non-Fatal Injury     Cyclist Collisions
# 10572              Daylight      Dry  Non-Fatal Injury     Cyclist Collisions
# 14730      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 10474      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 12177              Daylight      Dry             Fatal  Pedestrian Collisions
# 14723      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 10414              Daylight      Dry  Non-Fatal Injury              SMV Other
# 14740              Daylight      Wet  Non-Fatal Injury  Pedestrian Collisions
# 10397              Daylight      Dry  Non-Fatal Injury               Rear End
# 14715      Dark, artificial      Dry  Non-Fatal Injury              SMV Other
# 12169              Daylight      Dry  Non-Fatal Injury              SMV Other
# 12165              Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 10318              Daylight      Dry  Non-Fatal Injury              SMV Other
# 10312              Daylight      Dry  Non-Fatal Injury              SMV Other
# 12164              Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 6277               Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 14747              Daylight      Wet  Non-Fatal Injury  Pedestrian Collisions
# 12601              Daylight      Dry             Fatal  Pedestrian Collisions
# 10404              Daylight      Dry  Non-Fatal Injury               Rear End
# 14767  Daylight, artificial      Dry  Non-Fatal Injury  Pedestrian Collisions
# 12530              Daylight      Dry             Fatal              SMV Other
# 10606              Daylight      Dry  Non-Fatal Injury  Pedestrian Collisions
# 1817               Daylight      Dry  Non-Fatal Injury            Approaching
# 12701                  Dusk      Dry  Non-Fatal Injury  Pedestrian Collisions
# 12044      Dark, artificial      Wet  Non-Fatal Injury              SMV Other
# 7671                   Dark      Dry  Non-Fatal Injury  Pedestrian Collisions
# 2652               Daylight      Wet  Non-Fatal Injury               Rear End
#
#                  INVTYPE    INVAGE INJURY  FATAL_NO  INITDIR  \
# 7796          Pedestrian  75 to 79  Fatal      19.0    South
# 6045          Pedestrian  45 to 49  Major       NaN     East
# 6044              Driver   unknown   None       NaN    North
# 10565             Driver  35 to 39   None       NaN     East
# 10572            Cyclist  30 to 34  Major       NaN  Unknown
# 14730             Driver  25 to 29  Minor       NaN    North
# 10474             Driver  20 to 24  Major       NaN     East
# 12177             Driver  65 to 69   None       NaN     East
# 14723          Passenger  20 to 24  Major       NaN      NaN
# 10414             Driver  60 to 64  Major       NaN    South
# 14740         Pedestrian  10 to 14  Minor       NaN    North
# 10397             Driver  35 to 39  Minor       NaN    South
# 14715          Passenger  20 to 24  Major       NaN      NaN
# 12169             Driver  75 to 79  Major       NaN    South
# 12165         Pedestrian  40 to 44  Major       NaN  Unknown
# 10318  Motorcycle Driver  35 to 39  Major       NaN    South
# 10312             Driver  65 to 69  Major       NaN    North
# 12164          Passenger  55 to 59   None       NaN      NaN
# 6277          Pedestrian  55 to 59  Major       NaN    South
# 14747             Driver  35 to 39   None       NaN    North
# 12601         Pedestrian  80 to 84  Fatal      57.0  Unknown
# 10404             Driver  25 to 29  Major       NaN    South
# 14767             Driver  70 to 74   None       NaN    North
# 12530             Driver  55 to 59  Fatal      46.0     West
# 10606         Pedestrian  70 to 74  Major       NaN    South
# 1817       Vehicle Owner   unknown   None       NaN      NaN
# 12701         Pedestrian  50 to 54  Major       NaN     West
# 12044  Motorcycle Driver  25 to 29  Major       NaN     East
# 7671          Pedestrian  50 to 54  Major       NaN    South
# 2652              Driver  45 to 49  Major       NaN     East
#
#                          VEHTYPE                           MANOEUVER  \
# 7796                       Other                                 NaN
# 6045                       Other                                 NaN
# 6044   Automobile, Station Wagon  Pulling Away from Shoulder or Curb
# 10565  Automobile, Station Wagon                         Going Ahead
# 10572                    Bicycle                             Unknown
# 14730  Automobile, Station Wagon                         Going Ahead
# 10474  Automobile, Station Wagon                         Going Ahead
# 12177  Automobile, Station Wagon                       Turning Right
# 14723                        NaN                                 NaN
# 10414  Automobile, Station Wagon                         Going Ahead
# 14740                        NaN                                 NaN
# 10397  Automobile, Station Wagon                         Going Ahead
# 14715                        NaN                                 NaN
# 12169  Automobile, Station Wagon                         Going Ahead
# 12165                        NaN                                 NaN
# 10318                 Motorcycle                         Going Ahead
# 10312  Automobile, Station Wagon                       Turning Right
# 12164                        NaN                                 NaN
# 6277                       Other                                 NaN
# 14747  Automobile, Station Wagon                        Turning Left
# 12601                        NaN                                 NaN
# 10404  Automobile, Station Wagon                 Slowing or Stopping
# 14767  Automobile, Station Wagon                         Going Ahead
# 12530  Automobile, Station Wagon                         Going Ahead
# 10606                        NaN                                 NaN
# 1817                       Other                                 NaN
# 12701                        NaN                                 NaN
# 12044                 Motorcycle                         Going Ahead
# 7671                       Other                                 NaN
# 2652   Automobile, Station Wagon                             Stopped
#
#                             DRIVACT                            DRIVCOND  \
# 7796                            NaN                                 NaN
# 6045                            NaN                                 NaN
# 6044                            NaN                                 NaN
# 10565                         Other                             Unknown
# 10572                           NaN                                 NaN
# 14730                         Other  Ability Impaired, Alcohol Over .08
# 10474                  Lost control                             Fatigue
# 12177                  Lost control                             Unknown
# 14723                           NaN                                 NaN
# 10414                  Lost control                             Unknown
# 14740                           NaN                                 NaN
# 10397  Failed to Yield Right of Way                              Normal
# 14715                           NaN                                 NaN
# 12169                  Lost control                             Unknown
# 12165                           NaN                                 NaN
# 10318                  Lost control                              Normal
# 10312                  Lost control                              Normal
# 12164                           NaN                                 NaN
# 6277                            NaN                                 NaN
# 14747              Driving Properly                              Normal
# 12601                           NaN                                 NaN
# 10404              Driving Properly                              Normal
# 14767              Driving Properly                              Normal
# 12530                  Lost control      Medical or Physical Disability
# 10606                           NaN                                 NaN
# 1817                            NaN                                 NaN
# 12701                           NaN                                 NaN
# 12044                  Lost control                         Inattentive
# 7671                            NaN                                 NaN
# 2652            Following too Close                         Inattentive
#
#                                                  PEDTYPE  \
# 7796                  Pedestrian hit at private driveway
# 6045                         Pedestrian hit at mid-block
# 6044                                                 NaN
# 10565                                                NaN
# 10572                                                NaN
# 14730                                                NaN
# 10474                                                NaN
# 12177                                                NaN
# 14723                                                NaN
# 10414                                                NaN
# 14740  Vehicle is going straight thru inter.while ped...
# 10397                                                NaN
# 14715                                                NaN
# 12169                                                NaN
# 12165                        Pedestrian hit at mid-block
# 10318                                                NaN
# 10312                                                NaN
# 12164                                                NaN
# 6277   Vehicle turns left while ped crosses without R...
# 14747                                                NaN
# 12601           Vehicle is reversing and hits pedestrian
# 10404                                                NaN
# 14767                                                NaN
# 12530                                                NaN
# 10606           Vehicle is reversing and hits pedestrian
# 1817                                                 NaN
# 12701                        Pedestrian hit at mid-block
# 12044                                                NaN
# 7671                         Pedestrian hit at mid-block
# 2652                                                 NaN
#
#                              PEDACT      PEDCOND  \
# 7796        On Sidewalk or Shoulder      Unknown
# 6045   Crossing, no Traffic Control       Normal
# 6044                            NaN          NaN
# 10565                           NaN          NaN
# 10572                           NaN          NaN
# 14730                           NaN          NaN
# 10474                           NaN          NaN
# 12177                           NaN          NaN
# 14723                           NaN          NaN
# 10414                           NaN          NaN
# 14740    Crossing with right of way       Normal
# 10397                           NaN          NaN
# 14715                           NaN          NaN
# 12169                           NaN          NaN
# 12165                         Other       Normal
# 10318                           NaN          NaN
# 10312                           NaN          NaN
# 12164                           NaN          NaN
# 6277   Crossing, no Traffic Control  Inattentive
# 14747                           NaN          NaN
# 12601       On Sidewalk or Shoulder      Unknown
# 10404                           NaN          NaN
# 14767                           NaN          NaN
# 12530                           NaN          NaN
# 10606                         Other      Unknown
# 1817                            NaN          NaN
# 12701  Crossing, no Traffic Control  Inattentive
# 12044                           NaN          NaN
# 7671   Crossing, no Traffic Control       Normal
# 2652                            NaN          NaN
#
#                                               CYCLISTYPE CYCACT  CYCCOND  \
# 7796                                                 NaN    NaN      NaN
# 6045                                                 NaN    NaN      NaN
# 6044                                                 NaN    NaN      NaN
# 10565                                                NaN    NaN      NaN
# 10572  Motorist without ROW drives into path of cycli...  Other  Unknown
# 14730                                                NaN    NaN      NaN
# 10474                                                NaN    NaN      NaN
# 12177                                                NaN    NaN      NaN
# 14723                                                NaN    NaN      NaN
# 10414                                                NaN    NaN      NaN
# 14740                                                NaN    NaN      NaN
# 10397                                                NaN    NaN      NaN
# 14715                                                NaN    NaN      NaN
# 12169                                                NaN    NaN      NaN
# 12165                                                NaN    NaN      NaN
# 10318                                                NaN    NaN      NaN
# 10312                                                NaN    NaN      NaN
# 12164                                                NaN    NaN      NaN
# 6277                                                 NaN    NaN      NaN
# 14747                                                NaN    NaN      NaN
# 12601                                                NaN    NaN      NaN
# 10404                                                NaN    NaN      NaN
# 14767                                                NaN    NaN      NaN
# 12530                                                NaN    NaN      NaN
# 10606                                                NaN    NaN      NaN
# 1817                                                 NaN    NaN      NaN
# 12701                                                NaN    NaN      NaN
# 12044                                                NaN    NaN      NaN
# 7671                                                 NaN    NaN      NaN
# 2652                                                 NaN    NaN      NaN
#
#       PEDESTRIAN CYCLIST AUTOMOBILE MOTORCYCLE TRUCK TRSN_CITY_VEH EMERG_VEH  \
# 7796         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 6045         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 6044         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10565        NaN     Yes        Yes        NaN   NaN           NaN       NaN
# 10572        NaN     Yes        Yes        NaN   NaN           NaN       NaN
# 14730        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 10474        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12177        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 14723        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 10414        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14740        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10397        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14715        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12169        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12165        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10318        NaN     NaN        NaN        Yes   NaN           NaN       NaN
# 10312        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12164        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 6277         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 14747        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 12601        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 10404        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 14767        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 12530        NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 10606        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 1817         NaN     NaN        Yes        NaN   NaN           NaN       NaN
# 12701        Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 12044        NaN     NaN        NaN        Yes   NaN           NaN       NaN
# 7671         Yes     NaN        Yes        NaN   NaN           NaN       NaN
# 2652         NaN     NaN        Yes        NaN   NaN           NaN       NaN
#
#       PASSENGER SPEEDING AG_DRIV REDLIGHT ALCOHOL DISABILITY HOOD_158  \
# 7796        NaN      NaN     NaN      NaN     NaN        NaN       36
# 6045        NaN      NaN     NaN      NaN     NaN        NaN       62
# 6044        NaN      NaN     NaN      NaN     NaN        NaN       62
# 10565       NaN      NaN     NaN      NaN     NaN        NaN       25
# 10572       NaN      NaN     NaN      NaN     NaN        NaN       25
# 14730       Yes      NaN     NaN      NaN     Yes        NaN      142
# 10474       NaN      NaN     NaN      NaN     NaN        NaN        7
# 12177       NaN      NaN     NaN      NaN     NaN        NaN       63
# 14723       Yes      NaN     NaN      NaN     Yes        NaN      142
# 10414       NaN      NaN     NaN      NaN     NaN        NaN        1
# 14740       NaN      NaN     Yes      Yes     NaN        NaN       35
# 10397       NaN      NaN     Yes      NaN     NaN        NaN       42
# 14715       Yes      NaN     NaN      NaN     Yes        NaN      142
# 12169       NaN      NaN     Yes      NaN     NaN        NaN      155
# 12165       Yes      NaN     NaN      NaN     NaN        NaN      171
# 10318       NaN      NaN     Yes      NaN     NaN        NaN       57
# 10312       NaN      Yes     Yes      NaN     NaN        NaN       64
# 12164       Yes      NaN     NaN      NaN     NaN        NaN      171
# 6277        NaN      NaN     NaN      NaN     NaN        NaN       12
# 14747       NaN      NaN     Yes      Yes     NaN        NaN       35
# 12601       NaN      NaN     Yes      NaN     NaN        NaN       27
# 10404       NaN      NaN     Yes      NaN     NaN        NaN       42
# 14767       Yes      NaN     NaN      NaN     NaN        NaN       47
# 12530       NaN      NaN     NaN      NaN     NaN        Yes       18
# 10606       NaN      NaN     NaN      NaN     NaN        NaN       95
# 1817        NaN      Yes     Yes      NaN     Yes        NaN      141
# 12701       NaN      NaN     NaN      NaN     NaN        NaN        1
# 12044       NaN      NaN     NaN      NaN     NaN        NaN       19
# 7671        NaN      NaN     NaN      NaN     NaN        NaN       83
# 2652        NaN      NaN     Yes      NaN     NaN        NaN       33
#
#                       NEIGHBOURHOOD_158 HOOD_140  \
# 7796                   Newtonbrook West       36
# 6045                  East End-Danforth       62
# 6044                  East End-Danforth       62
# 10565            Glenfield-Jane Heights       25
# 10572            Glenfield-Jane Heights       25
# 14730                      Woburn North      137
# 10474  Willowridge-Martingrove-Richview        7
# 12177                       The Beaches       63
# 14723                      Woburn North      137
# 10414            West Humber-Clairville        1
# 14740               Westminster-Branson       35
# 10397                 Banbury-Don Mills       42
# 14715                      Woburn North      137
# 12169                         Downsview       26
# 12165          Junction-Wallace Emerson       93
# 10318                   Broadview North       57
# 10312                 Woodbine Corridor       64
# 12164          Junction-Wallace Emerson       93
# 6277                      Markland Wood       12
# 14747               Westminster-Branson       35
# 12601           York University Heights       27
# 10404                 Banbury-Don Mills       42
# 14767                Don Valley Village       47
# 12530                       New Toronto       18
# 10606                             Annex       95
# 1817          Golfdale-Cedarbrae-Woburn      137
# 12701            West Humber-Clairville        1
# 12044                       Long Branch       19
# 7671                     Dufferin Grove       83
# 2652                       Clanton Park       33
#
#                               NEIGHBOURHOOD_140 DIVISION  ObjectId  SEASON  \
# 7796                      Newtonbrook West (36)      D32      7797  Summer
# 6045                     East End-Danforth (62)      D55      6046  Spring
# 6044                     East End-Danforth (62)      D55      6045  Spring
# 10565               Glenfield-Jane Heights (25)      D31     10566  Summer
# 10572               Glenfield-Jane Heights (25)      D31     10573  Summer
# 14730                              Woburn (137)      D43     14731  Winter
# 10474      Willowridge-Martingrove-Richview (7)      D23     10475  Summer
# 12177                          The Beaches (63)      D55     12178  Spring
# 14723                              Woburn (137)      D43     14724  Winter
# 10414                West Humber-Clairville (1)      D23     10415  Summer
# 14740                  Westminster-Branson (35)      D32     14741  Spring
# 10397                    Banbury-Don Mills (42)      D33     10398  Summer
# 14715                              Woburn (137)      D43     14716  Winter
# 12169                 Downsview-Roding-CFB (26)      D31     12170  Autumn
# 12165  Dovercourt-Wallace Emerson-Junction (93)      D11     12166  Autumn
# 10318                      Broadview North (57)      D55     10319  Summer
# 10312                    Woodbine Corridor (64)      D55     10313  Summer
# 12164  Dovercourt-Wallace Emerson-Junction (93)      D11     12165  Autumn
# 6277                         Markland Wood (12)      D22      6278  Spring
# 14747                  Westminster-Branson (35)      D32     14748  Spring
# 12601              York University Heights (27)      D31     12602  Autumn
# 10404                    Banbury-Don Mills (42)      D33     10405  Summer
# 14767                   Don Valley Village (47)      D33     14768  Spring
# 12530                          New Toronto (18)      D22     12531  Summer
# 10606                                Annex (95)      D53     10607  Summer
# 1817                               Woburn (137)      D43      1818  Winter
# 12701                West Humber-Clairville (1)      D23     12702  Winter
# 12044                          Long Branch (19)      D22     12045  Summer
# 7671                        Dufferin Grove (83)      D11      7672  Autumn
# 2652                          Clanton Park (33)      D32      2653  Autumn
#
#        Year  Month  Day  ACC_NUM2  ACC_NUM
# 7796   2011      8   13      -1.0     -1.0
# 6045   2011      3   25      -1.0     -1.0
# 6044   2011      3   25      -1.0     -1.0
# 10565  2014      7   18      -1.0     -1.0
# 10572  2014      7   18      -1.0     -1.0
# 14730  2018      2   23      -1.0     -1.0
# 10474  2014      7   14      -1.0     -1.0
# 12177  2016      5    3      -1.0     -1.0
# 14723  2018      2   23      -1.0     -1.0
# 10414  2014      7   10      -1.0     -1.0
# 14740  2018      4   12      -1.0     -1.0
# 10397  2014      7   10      -1.0     -1.0
# 14715  2018      2   23      -1.0     -1.0
# 12169  2015     10   21      -1.0     -1.0
# 12165  2015     10   20      -1.0     -1.0
# 10318  2014      7    6      -1.0     -1.0
# 10312  2014      7    2      -1.0     -1.0
# 12164  2015     10   20      -1.0     -1.0
# 6277   2011      4   20      -1.0     -1.0
# 14747  2018      4   12      -1.0     -1.0
# 12601  2016      9   16      -1.0     -1.0
# 10404  2014      7   10      -1.0     -1.0
# 14767  2018      5   22      -1.0     -1.0
# 12530  2016      7   12      -1.0     -1.0
# 10606  2014      7   23      -1.0     -1.0
# 1817   2007      2   21      -1.0     -1.0
# 12701  2016      2   29      -1.0     -1.0
# 12044  2016      8   13      -1.0     -1.0
# 7671   2011      9   25      -1.0     -1.0
# 2652   2007     10    6      -1.0     -1.0
